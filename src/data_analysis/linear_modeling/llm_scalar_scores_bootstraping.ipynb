# %%
import sys
from pathlib import Path

sys.path.append(r"/home/maxim-shibanov/Projects_Py/Risk-and-return-prediction-with-LLM/src")

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import copy
import matplotlib.lines as mlines
import re
from joblib import Parallel, delayed
from tqdm.auto import tqdm
from textwrap import dedent
from linearmodels.panel import PanelOLS
from io import StringIO
from sklearn.preprocessing import StandardScaler

from data_analysis.data_fetcher.data_fetcher_class import DataFetcher
from data_collection.consts import  DB_PARAMS

# %%
fetcher = DataFetcher(
    db_params=DB_PARAMS,
    reports_table="reports",
    targets_table="targets_yf",
)
# Out:
# Available regressors:
#  - avg_default_verbolizer
#  - avg_shrink_verbolizer
#  - doc_len
#  - eps_surprise
#  - f_size
#  - full_list_default_verbolizer
#  - full_list_shrink_verbolizer
#  - hv_orig_score
#  - lm_orig_score
#  - max_abs_default
#  - max_abs_shrink
#  - max_default_verbolizer
#  - max_shrink_verbolizer
#  - md_hv1
#  - md_hv2
#  - md_hv3
#  - md_lm1
#  - md_lm2
#  - md_lm3
#  - min_default_verbolizer
#  - min_shrink_verbolizer
#  - stretch_default
#  - stretch_shrink
# Available sectors:
#  - Technology (92)
#  - Industrials (86)
#  - Financial Services (85)
#  - Healthcare (66)
#  - Consumer Cyclical (58)
#  - Consumer Defensive (40)
#  - Real Estate (32)
#  - Utilities (32)
#  - Energy (30)
#  - Basic Materials (23)
#  - Communication Services (22)
# /home/maxim-shibanov/Projects_Py/Risk-and-return-prediction-with-LLM/src/data_analysis/data_fetcher/data_fetcher_class.py:111: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
# /home/maxim-shibanov/Projects_Py/Risk-and-return-prediction-with-LLM/src/data_analysis/data_fetcher/data_fetcher_class.py:92: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
df = fetcher.fetch_data(
      regressors=[
       'avg_default_verbolizer', 
       'avg_shrink_verbolizer',
       'max_abs_default',
       'max_abs_shrink',
        'max_default_verbolizer',
        'max_shrink_verbolizer',
        'min_default_verbolizer',
        'min_shrink_verbolizer',
        'eps_surprise',
        'f_size',
        'doc_len'
       ],
   prepare_fixed_effects=True
)
# Out:
# /home/maxim-shibanov/Projects_Py/Risk-and-return-prediction-with-LLM/src/data_analysis/data_fetcher/data_fetcher_class.py:130: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
# /home/maxim-shibanov/Projects_Py/Risk-and-return-prediction-with-LLM/src/data_analysis/data_fetcher/data_fetcher_class.py:161: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, conn)
# /home/maxim-shibanov/Projects_Py/Risk-and-return-prediction-with-LLM/src/data_analysis/data_fetcher/data_fetcher_class.py:169: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   companies_df = pd.read_sql_query(query, conn)

# %%
df['f_size'] = df['f_size'] / 10**10

# %% [markdown]
# r_vol ~ (avg_default_verbolizer, avg_shrink_verbolizer, max_abs_default, max_default_verbolizer, max_shrink_verbolizer)
#
# returns ~ max_abs_default, max_abs_shrink, min_default_verbolizer, min_shrink_verbolizer
#
# e_returns ~ max_abs_shrink,
#
# abn_returns ~ max_abs_shrink, max_default_verbolizer, max_shrink_verbolizer, min_default_verbolizer, min_shrink_verbolizer

# %%
class FEModeler:
    """
    A class to run panel fixed effects regressions using PanelOLS
    and extract key parameter statistics for a specified regressor.

    Attributes:
        df: The input panel data.
        var_names: Column names of the input DataFrame.
        params_dict: Dictionary storing regression parameters for each independent variable.
    """

    def __init__(self, df: pd.DataFrame, scale: bool = False):
        """
        Initialize the FEModeler with panel data.

        Args:
            df: Panel DataFrame with MultiIndex (entity, time).
            scale: Whether to standardize the regressors.
        """
        self.original_df = df.copy()
        self.df = df.copy()
        self.var_names = df.columns
        self.params_dict = {}
        self.scale = scale

    @staticmethod
    def extract_params(summary, regressor_name: str) -> pd.Series:
        """
        Return just the coefficient (beta) for `regressor_name`
        PLUS all R-squared metrics.
        """

        # --- coefficient table ---
        html = summary.tables[1].as_html()
        coef_df = pd.read_html(StringIO(html), header=0, index_col=0)[0]
        beta = coef_df.loc[regressor_name, "Parameter"]

        # --- grab R²s from text ---
        txt = summary.as_text()
        def grab(label):
            m = re.search(fr"{label}:\s*([-\d.]+)", txt)
            return float(m.group(1)) if m else np.nan

        r2          = grab("R-squared")
        r2_between  = grab(r"R-squared \(Between\)")
        r2_within   = grab(r"R-squared \(Within\)")
        r2_overall  = grab(r"R-squared \(Overall\)")

        params_dict = {
                "beta": beta,
                "r2": r2,
                "r2_between": r2_between,
                "r2_within": r2_within,
                "r2_overall": r2_overall,
            }
        return params_dict
    

    def fit(self, data: pd.DataFrame, formula: str):
        """
        Fit a fixed effects regression model using PanelOLS.

        Args:
            data: A subset of the full DataFrame containing required variables.
            formula: Regression formula in Patsy-style syntax.

        Returns:
            The regression summary object.
        """
        model = PanelOLS.from_formula(formula, data=data, check_rank=True)
        result = model.fit()
        return result.summary

    def compute(self) -> dict[str, list[pd.Series]]:
        """
        Run fixed effects regressions for all combinations of independent and dependent variables,
        and store the parameter summaries for each independent variable.

        Returns:
            A dictionary where keys are independent variable names,
            and values are lists of Series with parameter info for each dependent variable.        """
        
        ALLOWED = {
            "r_vol": [
                "avg_default_verbolizer", "avg_shrink_verbolizer",
                "max_abs_default", "max_default_verbolizer", "max_shrink_verbolizer",
            ],
            "returns": [
                "max_abs_default", "max_abs_shrink",
                "min_default_verbolizer", "min_shrink_verbolizer",
            ],
            "e_returns": ["max_abs_shrink"],
            "abn_returns": [
                "max_abs_shrink", "max_default_verbolizer",
                "max_shrink_verbolizer", "min_default_verbolizer",
                "min_shrink_verbolizer",
            ],
        }

        targets = ['returns', 'e_returns', 'abn_returns', 'r_vol']
        time_frames = ['2_day', '3_day', '4_day', '5_day', '6_day', '7_day', 'full_quarter' ]

        var_names = self.df.columns 

        for x in range(1, 9):
            # Targets starts from y index
            y = 12

            per_target_params = {}
            for target in targets:  
                if target not in per_target_params:
                    per_target_params[target] = {}

                for frame in time_frames:
                    reg_name = var_names[x]
                    if reg_name not in ALLOWED[target]:
                        y += 1  
                        continue  

                    data = self.df.iloc[:, [x, 9, 10, 11, y]].dropna().copy()

                    formula = f"{var_names[y]} ~ {var_names[x]} + eps_surprise + f_size + EntityEffects + TimeEffects"
                    try:
                        result_summary = self.fit(data, formula)
                        print(result_summary)
                        param_info = self.extract_params(result_summary, self.var_names[x])
                        per_target_params[target][var_names[y]] = param_info
                        
                    except Exception as e:
                        print(e)
                    y += 1

            self.params_dict[var_names[x]] = per_target_params

        return self.params_dict

# %%
class BootStraper:

    def __init__(self, df: pd.DataFrame, num_samples: int):
        self.df = df
        self.num_samples = num_samples
        self.resamples: list[pd.DataFrame] = []

    def create_resamples(self):
        
        def random_matrix(len_sample, num_samples):
            return np.random.randint(0, len_sample, size=(len_sample, num_samples)) 

        len_sample = len(df.index.levels[0])

        matrix = random_matrix(len_sample, self.num_samples)
        
        for sample in range(self.num_samples):
            col =  matrix[:, sample]

            level0_full = df.index.levels[0]
            selected_level0_values = level0_full[col]
            filtered_df = df.loc[selected_level0_values].copy()


            level0 = filtered_df.index.get_level_values(0).to_numpy()
            level1 = filtered_df.index.get_level_values(1).to_numpy()

            block_starts = np.r_[True, level0[1:] != level0[:-1]]
            block_ids = np.cumsum(block_starts) - 1 

            new_index = pd.MultiIndex.from_arrays(
                [block_ids, level1],
                names=filtered_df.index.names
            )

            filtered_df.index = new_index
            self.resamples.append(filtered_df)

    @staticmethod
    def fit_FE(df: pd.DataFrame):

        model = FEModeler(df=df, scale=False)
        return model.compute()
    
    @staticmethod
    def _deep_append(base: dict, new: dict):
        """
        Merge `new` into `base` in place.

        Rules
        -----
        • Internal nodes are plain dicts; recurse.
        • A terminal node is a dict whose *values are scalars* (not dicts).
          For terminals we build/extend **dicts of lists**, so after N
          draws every statistic key holds N values.
        """
        for key, val in new.items():

            # -------- leaf test: val is dict but none of its values is a dict
            is_leaf = isinstance(val, dict) and not any(
                isinstance(x, dict) for x in val.values()
            )

            # -------- branch doesn't exist yet
            if key not in base:
                if is_leaf:
                    # first encounter → start lists
                    base[key] = {k: [v] for k, v in val.items()}
                else:
                    base[key] = {}
                    BootStraper._deep_append(base[key], val)
                continue

            # -------- branch exists
            if is_leaf:
                # ensure existing branch is dict of lists
                for stat_k, stat_v in val.items():
                    if stat_k not in base[key]:
                        base[key][stat_k] = []
                    base[key][stat_k].append(stat_v)
            else:
                BootStraper._deep_append(base[key], val)

    @staticmethod
    def drop_nulls(d: dict):
        keys_to_del = {}

        for regressor in d:
            for target, value in d[regressor].items():
                if not d[regressor][target]:
                    if not value:                                  
                        keys_to_del.setdefault(regressor, []).append(target)

        for reg in keys_to_del:
            for target in keys_to_del[reg]:
                print(reg, keys_to_del[reg])
                del d[reg][target]

        return d

    def compute_obs(self):
        return self.fit_FE(self.df)

    def run(self, n_jobs: int = -1) -> dict:
        """
        * Creates all resamples,
        * fits FE regressions on each (in parallel),
        * returns a nested dict where every leaf is **a list of Series**
          (one Series per bootstrap draw).
        """
        #  1. resample list
        self.create_resamples()

        #  2. parallel estimation with progress bar
        computed = Parallel(n_jobs=n_jobs)(
            delayed(self.fit_FE)(res)
            for res in tqdm(self.resamples, desc="Bootstrapping")
        )

        #  3. combine
        params: dict = {}
        for res_dict in computed:
            self._deep_append(params, res_dict)
        
        params = self.drop_nulls(params)

        return params

# %%
BootStraper(df, 2).compute_obs()
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          two_day_r_vol   R-squared:                        0.0013
# Estimator:                   PanelOLS   R-squared (Between):             -0.1152
# No. Observations:               12968   R-squared (Within):               0.0048
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0896
# Time:                        22:30:24   Log-likelihood                 1.328e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      5.5983
# Entities:                         486   P-value                           0.0008
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             5.5983
#                                         P-value                           0.0008
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0908     0.0225    -4.0317     0.0001     -0.1349     -0.0466
# eps_surprise            2.762e-07  5.367e-07     0.5147     0.6068  -7.758e-07   1.328e-06
# f_size                 -3.559e-05  8.139e-05    -0.4373     0.6619     -0.0002      0.0001
# ==========================================================================================
#
# F-test for Poolability: 14.271
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        three_day_r_vol   R-squared:                        0.0016
# Estimator:                   PanelOLS   R-squared (Between):             -0.1428
# No. Observations:               12968   R-squared (Within):               0.0056
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1053
# Time:                        22:30:24   Log-likelihood                 1.286e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.6621
# Entities:                         486   P-value                           0.0002
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             6.6621
#                                         P-value                           0.0002
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1038     0.0233    -4.4596     0.0000     -0.1494     -0.0582
# eps_surprise            1.021e-07  5.545e-07     0.1842     0.8539  -9.849e-07   1.189e-06
# f_size                 -1.402e-05   8.41e-05    -0.1667     0.8676     -0.0002      0.0002
# ==========================================================================================
#
# F-test for Poolability: 10.168
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         four_day_r_vol   R-squared:                        0.0019
# Estimator:                   PanelOLS   R-squared (Between):             -0.1609
# No. Observations:               12968   R-squared (Within):               0.0064
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1180
# Time:                        22:30:24   Log-likelihood                 1.318e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.0541
# Entities:                         486   P-value                           0.0000
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             8.0541
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1110     0.0227    -4.8929     0.0000     -0.1555     -0.0666
# eps_surprise            9.283e-08   5.41e-07     0.1716     0.8638  -9.675e-07   1.153e-06
# f_size                 -3.215e-05  8.204e-05    -0.3919     0.6951     -0.0002      0.0001
# ==========================================================================================
#
# F-test for Poolability: 9.3557
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         five_day_r_vol   R-squared:                        0.0019
# Estimator:                   PanelOLS   R-squared (Between):             -0.1620
# No. Observations:               12968   R-squared (Within):               0.0060
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1135
# Time:                        22:30:24   Log-likelihood                 1.231e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.0121
# Entities:                         486   P-value                           0.0000
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             8.0121
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1162     0.0243    -4.7885     0.0000     -0.1638     -0.0686
# eps_surprise           -7.063e-08  5.784e-07    -0.1221     0.9028  -1.204e-06   1.063e-06
# f_size                  9.208e-05  8.772e-05     1.0496     0.2939  -7.987e-05      0.0003
# ==========================================================================================
#
# F-test for Poolability: 7.7769
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          six_day_r_vol   R-squared:                        0.0024
# Estimator:                   PanelOLS   R-squared (Between):             -0.1741
# No. Observations:               12968   R-squared (Within):               0.0071
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1239
# Time:                        22:30:24   Log-likelihood                  1.32e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9.7802
# Entities:                         486   P-value                           0.0000
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             9.7802
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1199     0.0227    -5.2943     0.0000     -0.1643     -0.0755
# eps_surprise           -2.112e-08  5.399e-07    -0.0391     0.9688  -1.079e-06   1.037e-06
# f_size                  9.356e-05  8.188e-05     1.1426     0.2532  -6.694e-05      0.0003
# ==========================================================================================
#
# F-test for Poolability: 8.2440
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        seven_day_r_vol   R-squared:                        0.0024
# Estimator:                   PanelOLS   R-squared (Between):             -0.1765
# No. Observations:               12968   R-squared (Within):               0.0073
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1251
# Time:                        22:30:24   Log-likelihood                 1.346e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9.8524
# Entities:                         486   P-value                           0.0000
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             9.8524
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1186     0.0222    -5.3411     0.0000     -0.1622     -0.0751
# eps_surprise           -1.493e-08  5.294e-07    -0.0282     0.9775  -1.053e-06   1.023e-06
# f_size                  8.123e-05  8.028e-05     1.0118     0.3116  -7.614e-05      0.0002
# ==========================================================================================
#
# F-test for Poolability: 8.3485
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           full_q_r_vol   R-squared:                        0.0039
# Estimator:                   PanelOLS   R-squared (Between):             -0.2130
# No. Observations:               12482   R-squared (Within):               0.0078
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1416
# Time:                        22:30:25   Log-likelihood                 1.345e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      15.593
# Entities:                         484   P-value                           0.0000
# Avg Obs:                       25.789   Distribution:                 F(3,11969)
# Min Obs:                       1.0000
# Max Obs:                       27.000   F-statistic (robust):             15.593
#                                         P-value                           0.0000
# Time periods:                      27   Distribution:                 F(3,11969)
# Avg Obs:                       462.30
# Min Obs:                       439.00
# Max Obs:                       483.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1053     0.0218    -4.8392     0.0000     -0.1479     -0.0626
# eps_surprise            9.549e-08  5.095e-07     0.1874     0.8513  -9.032e-07   1.094e-06
# f_size                    -0.0004  8.607e-05    -4.7622     0.0000     -0.0006     -0.0002
# ==========================================================================================
#
# F-test for Poolability: 11.603
# P-value: 0.0000
# Distribution: F(509,11969)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          two_day_r_vol   R-squared:                        0.0008
# Estimator:                   PanelOLS   R-squared (Between):             -0.0954
# No. Observations:               12968   R-squared (Within):               0.0029
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0744
# Time:                        22:30:25   Log-likelihood                 1.328e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      3.3327
# Entities:                         486   P-value                           0.0186
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             3.3327
#                                         P-value                           0.0186
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.0854     0.0278    -3.0754     0.0021     -0.1398     -0.0310
# eps_surprise           2.849e-07  5.369e-07     0.5307     0.5957  -7.674e-07   1.337e-06
# f_size                -3.488e-05  8.141e-05    -0.4284     0.6684     -0.0002      0.0001
# =========================================================================================
#
# F-test for Poolability: 14.522
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        three_day_r_vol   R-squared:                        0.0011
# Estimator:                   PanelOLS   R-squared (Between):             -0.1286
# No. Observations:               12968   R-squared (Within):               0.0040
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0949
# Time:                        22:30:25   Log-likelihood                 1.285e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.6195
# Entities:                         486   P-value                           0.0031
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             4.6195
#                                         P-value                           0.0031
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1064     0.0287    -3.7095     0.0002     -0.1627     -0.0502
# eps_surprise           1.089e-07  5.547e-07     0.1963     0.8443  -9.784e-07   1.196e-06
# f_size                -1.314e-05  8.412e-05    -0.1562     0.8759     -0.0002      0.0002
# =========================================================================================
#
# F-test for Poolability: 10.313
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         four_day_r_vol   R-squared:                        0.0015
# Estimator:                   PanelOLS   R-squared (Between):             -0.1550
# No. Observations:               12968   R-squared (Within):               0.0050
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1137
# Time:                        22:30:25   Log-likelihood                 1.318e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.3734
# Entities:                         486   P-value                           0.0003
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             6.3734
#                                         P-value                           0.0003
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1216     0.0280    -4.3472     0.0000     -0.1765     -0.0668
# eps_surprise           9.732e-08  5.411e-07     0.1799     0.8573  -9.633e-07   1.158e-06
# f_size                -3.115e-05  8.205e-05    -0.3797     0.7042     -0.0002      0.0001
# =========================================================================================
#
# F-test for Poolability: 9.4675
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         five_day_r_vol   R-squared:                        0.0015
# Estimator:                   PanelOLS   R-squared (Between):             -0.1562
# No. Observations:               12968   R-squared (Within):               0.0047
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1095
# Time:                        22:30:25   Log-likelihood                 1.231e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.4369
# Entities:                         486   P-value                           0.0002
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             6.4369
#                                         P-value                           0.0002
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1277     0.0299    -4.2667     0.0000     -0.1863     -0.0690
# eps_surprise          -6.606e-08  5.786e-07    -0.1142     0.9091    -1.2e-06   1.068e-06
# f_size                 9.312e-05  8.774e-05     1.0614     0.2885  -7.886e-05      0.0003
# =========================================================================================
#
# F-test for Poolability: 7.8800
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          six_day_r_vol   R-squared:                        0.0020
# Estimator:                   PanelOLS   R-squared (Between):             -0.1752
# No. Observations:               12968   R-squared (Within):               0.0060
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1248
# Time:                        22:30:25   Log-likelihood                  1.32e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.4746
# Entities:                         486   P-value                           0.0000
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             8.4746
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1371     0.0279    -4.9106     0.0000     -0.1919     -0.0824
# eps_surprise          -1.833e-08    5.4e-07    -0.0339     0.9729  -1.077e-06    1.04e-06
# f_size                 9.468e-05  8.189e-05     1.1562     0.2476  -6.584e-05      0.0003
# =========================================================================================
#
# F-test for Poolability: 8.3314
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        seven_day_r_vol   R-squared:                        0.0021
# Estimator:                   PanelOLS   R-squared (Between):             -0.1823
# No. Observations:               12968   R-squared (Within):               0.0065
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1292
# Time:                        22:30:25   Log-likelihood                 1.346e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.9220
# Entities:                         486   P-value                           0.0000
# Avg Obs:                       26.683   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             8.9220
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.14
# Min Obs:                       439.00
# Max Obs:                       486.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1389     0.0274    -5.0731     0.0000     -0.1926     -0.0852
# eps_surprise          -1.332e-08  5.295e-07    -0.0252     0.9799  -1.051e-06   1.024e-06
# f_size                 8.237e-05  8.029e-05     1.0258     0.3050  -7.502e-05      0.0002
# =========================================================================================
#
# F-test for Poolability: 8.4187
# P-value: 0.0000
# Distribution: F(512,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           full_q_r_vol   R-squared:                        0.0042
# Estimator:                   PanelOLS   R-squared (Between):             -0.2415
# No. Observations:               12482   R-squared (Within):               0.0089
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1603
# Time:                        22:30:25   Log-likelihood                 1.346e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      16.640
# Entities:                         484   P-value                           0.0000
# Avg Obs:                       25.789   Distribution:                 F(3,11969)
# Min Obs:                       1.0000
# Max Obs:                       27.000   F-statistic (robust):             16.640
#                                         P-value                           0.0000
# Time periods:                      27   Distribution:                 F(3,11969)
# Avg Obs:                       462.30
# Min Obs:                       439.00
# Max Obs:                       483.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1381     0.0268    -5.1532     0.0000     -0.1906     -0.0856
# eps_surprise            9.19e-08  5.094e-07     0.1804     0.8568  -9.067e-07    1.09e-06
# f_size                   -0.0004  8.606e-05    -4.7550     0.0000     -0.0006     -0.0002
# =========================================================================================
#
# F-test for Poolability: 11.544
# P-value: 0.0000
# Distribution: F(509,11969)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              two_day_r   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):              0.0322
# No. Observations:               12804   R-squared (Within):            3.509e-05
# Date:                Fri, May 16 2025   R-squared (Overall):              0.0016
# Time:                        22:30:25   Log-likelihood                -2.936e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.6690
# Entities:                         495   P-value                           0.5710
# Avg Obs:                       25.867   Distribution:                 F(3,12279)
# Min Obs:                       1.0000
# Max Obs:                       27.000   F-statistic (robust):             0.6690
#                                         P-value                           0.5710
# Time periods:                      28   Distribution:                 F(3,12279)
# Avg Obs:                       457.29
# Min Obs:                       2.0000
# Max Obs:                       493.00
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# max_abs_default     0.2817     0.2232     1.2619     0.2070     -0.1559      0.7192
# eps_surprise    -4.116e-06  1.483e-05    -0.2776     0.7813  -3.318e-05   2.495e-05
# f_size             -0.0013     0.0023    -0.5678     0.5702     -0.0058      0.0032
# ===================================================================================
#
# F-test for Poolability: 1.2181
# P-value: 0.0006
# Distribution: F(521,12279)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            three_day_r   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):              0.0467
# No. Observations:               13284   R-squared (Within):            6.237e-05
# Date:                Fri, May 16 2025   R-squared (Overall):              0.0021
# Time:                        22:30:25   Log-likelihood                -2.611e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.0256
# Entities:                         496   P-value                           0.3800
# Avg Obs:                       26.782   Distribution:                 F(3,12758)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             1.0256
#                                         P-value                           0.3800
# Time periods:                      28   Distribution:                 F(3,12758)
# Avg Obs:                       474.43
# Min Obs:                       452.00
# Max Obs:                       496.00
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# max_abs_default     0.2584     0.1554     1.6624     0.0964     -0.0463      0.5631
# eps_surprise    -3.311e-07  1.066e-05    -0.0311     0.9752  -2.122e-05   2.056e-05
# f_size             -0.0009     0.0016    -0.5480     0.5837     -0.0041      0.0023
# ===================================================================================
#
# F-test for Poolability: 1.5197
# P-value: 0.0000
# Distribution: F(522,12758)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:             four_day_r   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):              0.0214
# No. Observations:               13284   R-squared (Within):            5.899e-05
# Date:                Fri, May 16 2025   R-squared (Overall):              0.0010
# Time:                        22:30:25   Log-likelihood                -2.323e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.1351
# Entities:                         496   P-value                           0.3333
# Avg Obs:                       26.782   Distribution:                 F(3,12758)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             1.1351
#                                         P-value                           0.3333
# Time periods:                      28   Distribution:                 F(3,12758)
# Avg Obs:                       474.43
# Min Obs:                       452.00
# Max Obs:                       496.00
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# max_abs_default     0.1386     0.1251     1.1076     0.2680     -0.1066      0.3838
# eps_surprise    -1.587e-06  8.577e-06    -0.1850     0.8532   -1.84e-05   1.523e-05
# f_size             -0.0019     0.0013    -1.4578     0.1449     -0.0044      0.0007
# ===================================================================================
#
# F-test for Poolability: 1.7892
# P-value: 0.0000
# Distribution: F(522,12758)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:             five_day_r   R-squared:                        0.0005
# Estimator:                   PanelOLS   R-squared (Between):              0.0192
# No. Observations:               13284   R-squared (Within):            9.926e-05
# Date:                Fri, May 16 2025   R-squared (Overall):              0.0009
# Time:                        22:30:25   Log-likelihood                -2.087e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.9663
# Entities:                         496   P-value                           0.1167
# Avg Obs:                       26.782   Distribution:                 F(3,12758)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             1.9663
#                                         P-value                           0.1167
# Time periods:                      28   Distribution:                 F(3,12758)
# Avg Obs:                       474.43
# Min Obs:                       452.00
# Max Obs:                       496.00
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# max_abs_default     0.1396     0.1048     1.3331     0.1825     -0.0657      0.3450
# eps_surprise    -1.361e-06  7.183e-06    -0.1894     0.8498  -1.544e-05   1.272e-05
# f_size             -0.0022     0.0011    -2.0139     0.0440     -0.0043  -5.857e-05
# ===================================================================================
#
# F-test for Poolability: 2.0495
# P-value: 0.0000
# Distribution: F(522,12758)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              six_day_r   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):              0.0109
# No. Observations:               13284   R-squared (Within):           -9.037e-08
# Date:                Fri, May 16 2025   R-squared (Overall):              0.0004
# Time:                        22:30:25   Log-likelihood                -1.901e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.6056
# Entities:                         496   P-value                           0.1858
# Avg Obs:                       26.782   Distribution:                 F(3,12758)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             1.6056
#                                         P-value                           0.1858
# Time periods:                      28   Distribution:                 F(3,12758)
# Avg Obs:                       474.43
# Min Obs:                       452.00
# Max Obs:                       496.00
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# max_abs_default     0.0861     0.0910     0.9459     0.3442     -0.0923      0.2645
# eps_surprise    -4.223e-06  6.242e-06    -0.6766     0.4987  -1.646e-05   8.012e-06
# f_size             -0.0018     0.0009    -1.8566     0.0634     -0.0036   9.806e-05
# ===================================================================================
#
# F-test for Poolability: 2.5231
# P-value: 0.0000
# Distribution: F(522,12758)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:            seven_day_r   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):              0.0204
# No. Observations:               13284   R-squared (Within):           -8.828e-05
# Date:                Fri, May 16 2025   R-squared (Overall):              0.0008
# Time:                        22:30:25   Log-likelihood                -1.757e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.3078
# Entities:                         496   P-value                           0.2699
# Avg Obs:                       26.782   Distribution:                 F(3,12758)
# Min Obs:                       1.0000
# Max Obs:                       28.000   F-statistic (robust):             1.3078
#                                         P-value                           0.2699
# Time periods:                      28   Distribution:                 F(3,12758)
# Avg Obs:                       474.43
# Min Obs:                       452.00
# Max Obs:                       496.00
#
#                                 Parameter Estimates
# ===================================================================================
#                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------
# max_abs_default     0.0734     0.0817     0.8989     0.3687     -0.0867      0.2336
# eps_surprise    -3.964e-06  5.603e-06    -0.7075     0.4793  -1.495e-05   7.019e-06
# f_size             -0.0014     0.0009    -1.6122     0.1070     -0.0030      0.0003
# ===================================================================================
#
# F-test for Poolability: 2.8728
# P-value: 0.0000
# Distribution: F(522,12758)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:               full_q_r   R-squared:                        0.0027
# Estimator:                   PanelOLS   R-squared (Between):             -0.4395
# No. Observations:               12788   R-squared (Within):               0.0043
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0438
# Time:                        22:30:25   Log-likelihood                    27.656
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      10.918
# Entities:                         494   P-value                           0.0000
# Avg Obs:                       25.887   Distribution:                 F(3,12265)
# ...
# Time periods:                      27   Distribution:                 F(3,12265)
# Avg Obs:                       473.63
# Min Obs:                       452.00
# Max Obs:                       493.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# min_shrink_verbolizer    -0.0495     0.0286    -1.7278     0.0840     -0.1056      0.0067
# eps_surprise          -1.125e-06  1.186e-06    -0.9483     0.3430   -3.45e-06     1.2e-06
# f_size                   -0.0007     0.0002    -3.5134     0.0004     -0.0011     -0.0003
# =========================================================================================
#
# F-test for Poolability: 0.5972
# P-value: 1.0000
# Distribution: F(519,12265)
#
# Included effects: Entity, Time
# {'avg_default_verbolizer': {'returns': {},
#   'e_returns': {},
#   'abn_returns': {},
#   'r_vol': {'two_day_r_vol': {'beta': -0.0908,
#     'r2': 0.0013,
#     'r2_between': -0.1152,
#     'r2_within': 0.0048,
#     'r2_overall': -0.0896},
#    'three_day_r_vol': {'beta': -0.1038,
#     'r2': 0.0016,
#     'r2_between': -0.1428,
#     'r2_within': 0.0056,
#     'r2_overall': -0.1053},
#    'four_day_r_vol': {'beta': -0.111,
#     'r2': 0.0019,
#     'r2_between': -0.1609,
#     'r2_within': 0.0064,
#     'r2_overall': -0.118},
#    'five_day_r_vol': {'beta': -0.1162,
#     'r2': 0.0019,
#     'r2_between': -0.162,
#     'r2_within': 0.006,
#     'r2_overall': -0.1135},
#    'six_day_r_vol': {'beta': -0.1199,
#     'r2': 0.0024,
#     'r2_between': -0.1741,
#     'r2_within': 0.0071,
#     'r2_overall': -0.1239},
#    'seven_day_r_vol': {'beta': -0.1186,
#     'r2': 0.0024,
#     'r2_between': -0.1765,
#     'r2_within': 0.0073,
#     'r2_overall': -0.1251},
#    'full_q_r_vol': {'beta': -0.1053,
#     'r2': 0.0039,
#     'r2_between': -0.213,
#     'r2_within': 0.0078,
#     'r2_overall': -0.1416}}},
#  'avg_shrink_verbolizer': {'returns': {},
#   'e_returns': {},
#   'abn_returns': {},
#   'r_vol': {'two_day_r_vol': {'beta': -0.0854,
#     'r2': 0.0008,
#     'r2_between': -0.0954,
#     'r2_within': 0.0029,
#     'r2_overall': -0.0744},
#    'three_day_r_vol': {'beta': -0.1064,
#     'r2': 0.0011,
#     'r2_between': -0.1286,
#     'r2_within': 0.004,
#     'r2_overall': -0.0949},
#    'four_day_r_vol': {'beta': -0.1216,
#     'r2': 0.0015,
#     'r2_between': -0.155,
#     'r2_within': 0.005,
#     'r2_overall': -0.1137},
#    'five_day_r_vol': {'beta': -0.1277,
#     'r2': 0.0015,
#     'r2_between': -0.1562,
#     'r2_within': 0.0047,
#     'r2_overall': -0.1095},
#    'six_day_r_vol': {'beta': -0.1371,
#     'r2': 0.002,
#     'r2_between': -0.1752,
#     'r2_within': 0.006,
#     'r2_overall': -0.1248},
#    'seven_day_r_vol': {'beta': -0.1389,
#     'r2': 0.0021,
#     'r2_between': -0.1823,
#     'r2_within': 0.0065,
#     'r2_overall': -0.1292},
#    'full_q_r_vol': {'beta': -0.1381,
#     'r2': 0.0042,
#     'r2_between': -0.2415,
#     'r2_within': 0.0089,
#     'r2_overall': -0.1603}}},
#  'max_abs_default': {'returns': {'two_day_r': {'beta': 0.2817,
#     'r2': 0.0002,
#     'r2_between': 0.0322,
#     'r2_within': 3.509,
#     'r2_overall': 0.0016},
#    'three_day_r': {'beta': 0.2584,
#     'r2': 0.0002,
#     'r2_between': 0.0467,
#     'r2_within': 6.237,
#     'r2_overall': 0.0021},
#    'four_day_r': {'beta': 0.1386,
#     'r2': 0.0003,
#     'r2_between': 0.0214,
#     'r2_within': 5.899,
#     'r2_overall': 0.001},
#    'five_day_r': {'beta': 0.1396,
#     'r2': 0.0005,
#     'r2_between': 0.0192,
#     'r2_within': 9.926,
#     'r2_overall': 0.0009},
#    'six_day_r': {'beta': 0.0861,
#     'r2': 0.0004,
#     'r2_between': 0.0109,
#     'r2_within': -9.037,
#     'r2_overall': 0.0004},
#    'seven_day_r': {'beta': 0.0734,
#     'r2': 0.0003,
#     'r2_between': 0.0204,
#     'r2_within': -8.828,
#     'r2_overall': 0.0008},
#    'full_q_r': {'beta': -0.0665,
#     'r2': 0.0027,
#     'r2_between': -0.4395,
#     'r2_within': 0.0043,
#     'r2_overall': -0.0438}},
#   'e_returns': {},
#   'abn_returns': {},
#   'r_vol': {'two_day_r_vol': {'beta': -0.021,
#     'r2': 0.0006,
#     'r2_between': -0.0552,
#     'r2_within': 0.0024,
#     'r2_overall': -0.0429},
#    'three_day_r_vol': {'beta': -0.0287,
#     'r2': 0.001,
#     'r2_between': -0.0807,
#     'r2_within': 0.0032,
#     'r2_overall': -0.0594},
#    'four_day_r_vol': {'beta': -0.0289,
#     'r2': 0.0011,
#     'r2_between': -0.0856,
#     'r2_within': 0.0032,
#     'r2_overall': -0.0627},
#    'five_day_r_vol': {'beta': -0.0233,
#     'r2': 0.0007,
#     'r2_between': -0.0614,
#     'r2_within': 0.0022,
#     'r2_overall': -0.0429},
#    'six_day_r_vol': {'beta': -0.0216,
#     'r2': 0.0007,
#     'r2_between': -0.0586,
#     'r2_within': 0.0022,
#     'r2_overall': -0.0416},
#    'seven_day_r_vol': {'beta': -0.0149,
#     'r2': 0.0004,
#     'r2_between': -0.0396,
#     'r2_within': 0.0014,
#     'r2_overall': -0.028},
#    'full_q_r_vol': {'beta': -0.021,
#     'r2': 0.0026,
#     'r2_between': -0.106,
#     'r2_within': 0.0033,
#     'r2_overall': -0.0708}}},
#  'max_abs_shrink': {'returns': {'two_day_r': {'beta': 0.5749,
#     'r2': 0.0004,
#     'r2_between': 0.0429,
#     'r2_within': 0.0002,
#     'r2_overall': 0.0023},
#    'three_day_r': {'beta': 0.6059,
#     'r2': 0.0008,
#     'r2_between': 0.0482,
#     'r2_within': 0.0005,
#     'r2_overall': 0.0025},
#    'four_day_r': {'beta': 0.4079,
#     'r2': 0.0007,
#     'r2_between': 0.0591,
#     'r2_within': 0.0005,
#     'r2_overall': 0.0031},
#    'five_day_r': {'beta': 0.3181,
#     'r2': 0.0008,
#     'r2_between': 0.0569,
#     'r2_within': 0.0004,
#     'r2_overall': 0.0029},
#    'six_day_r': {'beta': 0.1836,
#     'r2': 0.0005,
#     'r2_between': 0.0481,
#     'r2_within': 0.0002,
#     'r2_overall': 0.0023},
#    'seven_day_r': {'beta': 0.1823,
#     'r2': 0.0005,
#     'r2_between': 0.0745,
#     'r2_within': 2.254,
#     'r2_overall': 0.0035},
#    'full_q_r': {'beta': -0.0433,
#     'r2': 0.0021,
#     'r2_between': -0.298,
#     'r2_within': 0.0029,
#     'r2_overall': -0.03}},
#   'e_returns': {'two_day_e_r': {'beta': 0.5326,
#     'r2': 0.0003,
#     'r2_between': 0.0024,
#     'r2_within': 0.0003,
#     'r2_overall': 0.0004},
#    'three_day_e_r': {'beta': 0.461,
#     'r2': 0.0005,
#     'r2_between': -0.0109,
#     'r2_within': 0.0007,
#     'r2_overall': 0.0003},
#    'four_day_e_r': {'beta': 0.3222,
#     'r2': 0.0005,
#     'r2_between': 4.57,
#     'r2_within': 0.0007,
#     'r2_overall': 0.001},
#    'five_day_e_r': {'beta': 0.2642,
#     'r2': 0.0006,
#     'r2_between': -0.0011,
#     'r2_within': 0.0009,
#     'r2_overall': 0.0009},
#    'six_day_e_r': {'beta': 0.157,
#     'r2': 0.0004,
#     'r2_between': 0.0015,
#     'r2_within': 0.0007,
#     'r2_overall': 0.0007},
#    'seven_day_e_r': {'beta': 0.1687,
#     'r2': 0.0005,
#     'r2_between': 0.0117,
#     'r2_within': 0.0007,
#     'r2_overall': 0.0012},
#    'full_q_e_r': {'beta': -0.0346,
#     'r2': 0.002,
#     'r2_between': -0.2377,
#     'r2_within': 0.0026,
#     'r2_overall': -0.0136}},
#   'abn_returns': {'two_day_abn_r': {'beta': 0.5675,
#     'r2': 0.0008,
#     'r2_between': -0.0384,
#     'r2_within': 0.0006,
#     'r2_overall': -0.0012},
#    'three_day_abn_r': {'beta': 0.4993,
#     'r2': 0.001,
#     'r2_between': -0.0642,
#     'r2_within': 0.0009,
#     'r2_overall': -0.002},
#    'four_day_abn_r': {'beta': 0.4016,
#     'r2': 0.001,
#     'r2_between': -0.0551,
#     'r2_within': 0.001,
#     'r2_overall': -0.0011},
#    'five_day_abn_r': {'beta': 0.3621,
#     'r2': 0.0012,
#     'r2_between': -0.0624,
#     'r2_within': 0.0012,
#     'r2_overall': -0.0013},
#    'six_day_abn_r': {'beta': 0.2886,
#     'r2': 0.0011,
#     'r2_between': -0.0485,
#     'r2_within': 0.0011,
#     'r2_overall': -0.0008},
#    'seven_day_abn_r': {'beta': 0.2783,
#     'r2': 0.0011,
#     'r2_between': -0.0528,
#     'r2_within': 0.0011,
#     'r2_overall': -0.001},
#    'full_q_abn_r': {'beta': 0.0162,
#     'r2': 0.0011,
#     'r2_between': -0.1482,
#     'r2_within': 0.0019,
#     'r2_overall': -0.0005}},
#   'r_vol': {}},
#  'max_default_verbolizer': {'returns': {},
#   'e_returns': {},
#   'abn_returns': {'two_day_abn_r': {'beta': 0.8543,
#     'r2': 0.0007,
#     'r2_between': -0.2411,
#     'r2_within': 0.0007,
#     'r2_overall': -0.0104},
#    'three_day_abn_r': {'beta': 0.6798,
#     'r2': 0.0008,
#     'r2_between': -0.2531,
#     'r2_within': 0.0008,
#     'r2_overall': -0.0107},
#    'four_day_abn_r': {'beta': 0.515,
#     'r2': 0.0008,
#     'r2_between': -0.1953,
#     'r2_within': 0.0008,
#     'r2_overall': -0.0072},
#    'five_day_abn_r': {'beta': 0.4932,
#     'r2': 0.001,
#     'r2_between': -0.2664,
#     'r2_within': 0.0011,
#     'r2_overall': -0.0098},
#    'six_day_abn_r': {'beta': 0.4309,
#     'r2': 0.001,
#     'r2_between': -0.2654,
#     'r2_within': 0.0012,
#     'r2_overall': -0.0096},
#    'seven_day_abn_r': {'beta': 0.3913,
#     'r2': 0.001,
#     'r2_between': -0.2595,
#     'r2_within': 0.0012,
#     'r2_overall': -0.0093},
#    'full_q_abn_r': {'beta': 0.013,
#     'r2': 0.0011,
#     'r2_between': -0.1452,
#     'r2_within': 0.002,
#     'r2_overall': -0.0004}},
#   'r_vol': {'two_day_r_vol': {'beta': -0.0679,
#     'r2': 0.0016,
#     'r2_between': -0.1965,
#     'r2_within': 0.0061,
#     'r2_overall': -0.1528},
#    'three_day_r_vol': {'beta': -0.0777,
#     'r2': 0.002,
#     'r2_between': -0.2453,
#     'r2_within': 0.0061,
#     'r2_overall': -0.1812},
#    'four_day_r_vol': {'beta': -0.0705,
#     'r2': 0.0017,
#     'r2_between': -0.2314,
#     'r2_within': 0.0051,
#     'r2_overall': -0.1701},
#    'five_day_r_vol': {'beta': -0.0669,
#     'r2': 0.0014,
#     'r2_between': -0.2133,
#     'r2_within': 0.0042,
#     'r2_overall': -0.15},
#    'six_day_r_vol': {'beta': -0.0633,
#     'r2': 0.0015,
#     'r2_between': -0.2082,
#     'r2_within': 0.004,
#     'r2_overall': -0.149},
#    'seven_day_r_vol': {'beta': -0.0556,
#     'r2': 0.0012,
#     'r2_between': -0.1857,
#     'r2_within': 0.0033,
#     'r2_overall': -0.1325},
#    'full_q_r_vol': {'beta': -0.0149,
#     'r2': 0.002,
#     'r2_between': -0.0889,
#     'r2_within': 0.0021,
#     'r2_overall': -0.0596}}},
#  'max_shrink_verbolizer': {'returns': {},
#   'e_returns': {},
#   'abn_returns': {'two_day_abn_r': {'beta': 1.1761,
#     'r2': 0.001,
#     'r2_between': -0.3207,
#     'r2_within': 0.0008,
#     'r2_overall': -0.0142},
#    'three_day_abn_r': {'beta': 1.0026,
#     'r2': 0.0011,
#     'r2_between': -0.3956,
#     'r2_within': 0.001,
#     'r2_overall': -0.017},
#    'four_day_abn_r': {'beta': 0.7668,
#     'r2': 0.0011,
#     'r2_between': -0.3207,
#     'r2_within': 0.001,
#     'r2_overall': -0.0124},
#    'five_day_abn_r': {'beta': 0.6963,
#     'r2': 0.0013,
#     'r2_between': -0.3752,
#     'r2_within': 0.0013,
#     'r2_overall': -0.0142},
#    'six_day_abn_r': {'beta': 0.625,
#     'r2': 0.0013,
#     'r2_between': -0.4,
#     'r2_within': 0.0014,
#     'r2_overall': -0.0149},
#    'seven_day_abn_r': {'beta': 0.5847,
#     'r2': 0.0013,
#     'r2_between': -0.4251,
#     'r2_within': 0.0014,
#     'r2_overall': -0.0158},
#    'full_q_abn_r': {'beta': 0.0607,
#     'r2': 0.0013,
#     'r2_between': -0.0596,
#     'r2_within': 0.0023,
#     'r2_overall': 0.0008}},
#   'r_vol': {'two_day_r_vol': {'beta': -0.079,
#     'r2': 0.0015,
#     'r2_between': -0.1872,
#     'r2_within': 0.0051,
#     'r2_overall': -0.1456},
#    'three_day_r_vol': {'beta': -0.0898,
#     'r2': 0.0018,
#     'r2_between': -0.232,
#     'r2_within': 0.0051,
#     'r2_overall': -0.1713},
#    'four_day_r_vol': {'beta': -0.0884,
#     'r2': 0.0018,
#     'r2_between': -0.2384,
#     'r2_within': 0.0048,
#     'r2_overall': -0.1752},
#    'five_day_r_vol': {'beta': -0.0769,
#     'r2': 0.0013,
#     'r2_between': -0.2002,
#     'r2_within': 0.0035,
#     'r2_overall': -0.1408},
#    'six_day_r_vol': {'beta': -0.0716,
#     'r2': 0.0013,
#     'r2_between': -0.192,
#     'r2_within': 0.0033,
#     'r2_overall': -0.1373},
#    'seven_day_r_vol': {'beta': -0.0657,
#     'r2': 0.0011,
#     'r2_between': -0.1794,
#     'r2_within': 0.0029,
#     'r2_overall': -0.1279},
#    'full_q_r_vol': {'beta': -0.0276,
#     'r2': 0.0021,
#     'r2_between': -0.1177,
#     'r2_within': 0.0022,
#     'r2_overall': -0.0789}}},
#  'min_default_verbolizer': {'returns': {'two_day_r': {'beta': 0.3253,
#     'r2': 0.0001,
#     'r2_between': -0.0241,
#     'r2_within': 0.0001,
#     'r2_overall': -0.001},
#    'three_day_r': {'beta': 0.345,
#     'r2': 0.0002,
#     'r2_between': -0.0394,
#     'r2_within': 0.0003,
#     'r2_overall': -0.0013},
#    'four_day_r': {'beta': 0.2517,
#     'r2': 0.0003,
#     'r2_between': -0.0613,
#     'r2_within': 0.0004,
#     'r2_overall': -0.0023},
#    'five_day_r': {'beta': 0.2565,
#     'r2': 0.0006,
#     'r2_between': -0.0857,
#     'r2_within': 0.0006,
#     'r2_overall': -0.0034},
#    'six_day_r': {'beta': 0.2389,
#     'r2': 0.0006,
#     'r2_between': -0.0904,
#     'r2_within': 0.0008,
#     'r2_overall': -0.0035},
#    'seven_day_r': {'beta': 0.1829,
#     'r2': 0.0005,
#     'r2_between': -0.0784,
#     'r2_within': 0.0006,
#     'r2_overall': -0.0034},
#    'full_q_r': {'beta': -0.0806,
#     'r2': 0.0025,
#     'r2_between': -0.0952,
#     'r2_within': 0.0015,
#     'r2_overall': -0.0095}},
#   'e_returns': {},
#   'abn_returns': {'two_day_abn_r': {'beta': 0.3076,
#     'r2': 0.0002,
#     'r2_between': -0.0211,
#     'r2_within': 2.86,
#     'r2_overall': -0.001},
#    'three_day_abn_r': {'beta': 0.204,
#     'r2': 0.0002,
#     'r2_between': -0.0243,
#     'r2_within': 0.0001,
#     'r2_overall': -0.0009},
#    'four_day_abn_r': {'beta': 0.1748,
#     'r2': 0.0003,
#     'r2_between': -0.034,
#     'r2_within': 0.0002,
#     'r2_overall': -0.0012},
#    'five_day_abn_r': {'beta': 0.1936,
#     'r2': 0.0005,
#     'r2_between': -0.0406,
#     'r2_within': 0.0004,
#     'r2_overall': -0.0014},
#    'six_day_abn_r': {'beta': 0.1747,
#     'r2': 0.0005,
#     'r2_between': -0.0461,
#     'r2_within': 0.0005,
#     'r2_overall': -0.0015},
#    'seven_day_abn_r': {'beta': 0.1285,
#     'r2': 0.0004,
#     'r2_between': -0.0372,
#     'r2_within': 0.0004,
#     'r2_overall': -0.0012},
#    'full_q_abn_r': {'beta': -0.0382,
#     'r2': 0.0013,
#     'r2_between': -0.208,
#     'r2_within': 0.0023,
#     'r2_overall': -0.0009}},
#   'r_vol': {}},
#  'min_shrink_verbolizer': {'returns': {'two_day_r': {'beta': 0.5997,
#     'r2': 0.0003,
#     'r2_between': -0.0276,
#     'r2_within': 0.0002,
#     'r2_overall': -0.0011},
#    'three_day_r': {'beta': 0.5812,
#     'r2': 0.0004,
#     'r2_between': -0.0424,
#     'r2_within': 0.0006,
#     'r2_overall': -0.0011},
#    'four_day_r': {'beta': 0.4326,
#     'r2': 0.0005,
#     'r2_between': -0.0635,
#     'r2_within': 0.0007,
#     'r2_overall': -0.0021},
#    'five_day_r': {'beta': 0.3844,
#     'r2': 0.0007,
#     'r2_between': -0.0827,
#     'r2_within': 0.0009,
#     'r2_overall': -0.0029},
#    'six_day_r': {'beta': 0.3575,
#     'r2': 0.0008,
#     'r2_between': -0.0865,
#     'r2_within': 0.0012,
#     'r2_overall': -0.0029},
#    'seven_day_r': {'beta': 0.2792,
#     'r2': 0.0006,
#     'r2_between': -0.0763,
#     'r2_within': 0.001,
#     'r2_overall': -0.003},
#    'full_q_r': {'beta': -0.0823,
#     'r2': 0.0024,
#     'r2_between': -0.1178,
#     'r2_within': 0.0014,
#     'r2_overall': -0.012}},
#   'e_returns': {},
#   'abn_returns': {'two_day_abn_r': {'beta': 0.4576,
#     'r2': 0.0003,
#     'r2_between': -0.021,
#     'r2_within': 4.527,
#     'r2_overall': -0.0009},
#    'three_day_abn_r': {'beta': 0.2957,
#     'r2': 0.0002,
#     'r2_between': -0.0234,
#     'r2_within': 0.0001,
#     'r2_overall': -0.0009},
#    'four_day_abn_r': {'beta': 0.2581,
#     'r2': 0.0004,
#     'r2_between': -0.0334,
#     'r2_within': 0.0003,
#     'r2_overall': -0.0012},
#    'five_day_abn_r': {'beta': 0.2555,
#     'r2': 0.0006,
#     'r2_between': -0.0376,
#     'r2_within': 0.0004,
#     'r2_overall': -0.0013},
#    'six_day_abn_r': {'beta': 0.229,
#     'r2': 0.0006,
#     'r2_between': -0.0427,
#     'r2_within': 0.0005,
#     'r2_overall': -0.0014},
#    'seven_day_abn_r': {'beta': 0.1781,
#     'r2': 0.0005,
#     'r2_between': -0.036,
#     'r2_within': 0.0003,
#     'r2_overall': -0.0012},
#    'full_q_abn_r': {'beta': -0.0495,
#     'r2': 0.0013,
#     'r2_between': -0.22,
#     'r2_within': 0.0024,
#     'r2_overall': -0.001}},
#   'r_vol': {}}}

# %%
d = BootStraper(df, 2).run()
# Out:
# Bootstrapping:   0%|          | 0/2 [00:00<?, ?it/s]
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          two_day_r_vol   R-squared:                        0.0013
# Estimator:                   PanelOLS   R-squared (Between):             -0.1021
# No. Observations:               12969   R-squared (Within):               0.0052
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0805
# Time:                        22:30:31   Log-likelihood                 1.322e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      5.3657
# Entities:                         487   P-value                           0.0011
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             5.3657
#                                         P-value                           0.0011
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0889     0.0227    -3.9121     0.0001     -0.1334     -0.0443
# eps_surprise           -1.402e-07  6.531e-07    -0.2146     0.8301   -1.42e-06    1.14e-06
# f_size                  6.251e-05  7.561e-05     0.8268     0.4084  -8.569e-05      0.0002
# ==========================================================================================
#
# F-test for Poolability: 14.336
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        three_day_r_vol   R-squared:                        0.0014
# Estimator:                   PanelOLS   R-squared (Between):             -0.1283
# No. Observations:               12969   R-squared (Within):               0.0053
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0957
# Time:                        22:30:31   Log-likelihood                 1.275e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      5.7728
# Entities:                         487   P-value                           0.0006
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             5.7728
#                                         P-value                           0.0006
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0978     0.0236    -4.1495     0.0000     -0.1439     -0.0516
# eps_surprise           -2.477e-07  6.774e-07    -0.3657     0.7146  -1.575e-06    1.08e-06
# f_size                  6.073e-06  7.841e-05     0.0774     0.9383     -0.0001      0.0002
# ==========================================================================================
#
# F-test for Poolability: 10.022
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         four_day_r_vol   R-squared:                        0.0015
# Estimator:                   PanelOLS   R-squared (Between):             -0.1371
# No. Observations:               12969   R-squared (Within):               0.0054
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1017
# Time:                        22:30:31   Log-likelihood                 1.307e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.1387
# Entities:                         487   P-value                           0.0004
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             6.1387
#                                         P-value                           0.0004
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0975     0.0230    -4.2443     0.0000     -0.1426     -0.0525
# eps_surprise           -3.329e-07  6.607e-07    -0.5039     0.6143  -1.628e-06   9.621e-07
# f_size                  -4.07e-05  7.648e-05    -0.5321     0.5946     -0.0002      0.0001
# ==========================================================================================
#
# F-test for Poolability: 9.1726
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         five_day_r_vol   R-squared:                        0.0017
# Estimator:                   PanelOLS   R-squared (Between):             -0.1458
# No. Observations:               12969   R-squared (Within):               0.0048
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0946
# Time:                        22:30:31   Log-likelihood                 1.039e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      7.0224
# Entities:                         487   P-value                           0.0001
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             7.0224
#                                         P-value                           0.0001
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1152     0.0283    -4.0775     0.0000     -0.1706     -0.0598
# eps_surprise           -2.413e-07  8.124e-07    -0.2970     0.7665  -1.834e-06   1.351e-06
# f_size                     0.0002  9.405e-05     2.0406     0.0413   7.567e-06      0.0004
# ==========================================================================================
#
# F-test for Poolability: 6.0042
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          six_day_r_vol   R-squared:                        0.0022
# Estimator:                   PanelOLS   R-squared (Between):             -0.1719
# No. Observations:               12969   R-squared (Within):               0.0061
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1137
# Time:                        22:30:31   Log-likelihood                 1.127e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9.3176
# Entities:                         487   P-value                           0.0000
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             9.3176
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1278     0.0264    -4.8414     0.0000     -0.1795     -0.0760
# eps_surprise           -1.304e-07  7.589e-07    -0.1719     0.8636  -1.618e-06   1.357e-06
# f_size                     0.0002  8.785e-05     2.0590     0.0395   8.686e-06      0.0004
# ==========================================================================================
#
# F-test for Poolability: 6.2807
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        seven_day_r_vol   R-squared:                        0.0027
# Estimator:                   PanelOLS   R-squared (Between):             -0.1826
# No. Observations:               12969   R-squared (Within):               0.0071
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1230
# Time:                        22:30:31   Log-likelihood                 1.204e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      11.068
# Entities:                         487   P-value                           0.0000
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             11.068
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1317     0.0249    -5.2942     0.0000     -0.1804     -0.0829
# eps_surprise           -1.084e-07  7.151e-07    -0.1516     0.8795   -1.51e-06   1.293e-06
# f_size                     0.0002  8.277e-05     2.2050     0.0275   2.027e-05      0.0003
# ==========================================================================================
#
# F-test for Poolability: 6.7720
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          two_day_r_vol   R-squared:                        0.0006
# Estimator:                   PanelOLS   R-squared (Between):             -0.0652
# No. Observations:               12978   R-squared (Within):               0.0024
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0513
# Time:                        22:30:31   Log-likelihood                 1.271e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.4141
# Entities:                         485   P-value                           0.0646
# Avg Obs:                       26.759   Distribution:                 F(3,12463)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             2.4141
#                                         P-value                           0.0646
# Time periods:                      28   Distribution:                 F(3,12463)
# Avg Obs:                       463.50
# Min Obs:                       438.00
# Max Obs:                       485.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0530     0.0231    -2.3006     0.0214     -0.0982     -0.0078
# eps_surprise            1.069e-06  9.518e-07     1.1229     0.2615  -7.969e-07   2.935e-06
# f_size                    -0.0001     0.0001    -0.8583     0.3907     -0.0003      0.0001
# ==========================================================================================
#
# F-test for Poolability: 15.023
# P-value: 0.0000
# Distribution: F(511,12463)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           full_q_r_vol   R-squared:                        0.0042
# Estimator:                   PanelOLS   R-squared (Between):             -0.2776
# No. Observations:               12481   R-squared (Within):               0.0089
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1826
# Time:                        22:30:31   Log-likelihood                 1.293e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      16.939
# Entities:                         486   P-value                           0.0000
# Avg Obs:                       25.681   Distribution:                 F(3,11966)
# Min Obs:                       1.0000
# Max Obs:                       54.000   F-statistic (robust):             16.939
#                                         P-value                           0.0000
# Time periods:                      27   Distribution:                 F(3,11966)
# Avg Obs:                       462.26
# Min Obs:                       435.00
# Max Obs:                       485.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1603     0.0228    -7.0382     0.0000     -0.2049     -0.1156
# eps_surprise           -7.789e-09  6.435e-07    -0.0121     0.9903  -1.269e-06   1.253e-06
# f_size                 -9.651e-05  8.904e-05    -1.0838     0.2785     -0.0003   7.803e-05
# ==========================================================================================
#
# F-test for Poolability: 10.032
# P-value: 0.0000
# Distribution: F(511,11966)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        three_day_r_vol   R-squared:                        0.0012
# Estimator:                   PanelOLS   R-squared (Between):             -0.0907
# No. Observations:               12978   R-squared (Within):               0.0049
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0745
# Time:                        22:30:31   Log-likelihood                 1.534e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.7882
# Entities:                         485   P-value                           0.0025
# Avg Obs:                       26.759   Distribution:                 F(3,12463)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             4.7882
#                                         P-value                           0.0025
# Time periods:                      28   Distribution:                 F(3,12463)
# Avg Obs:                       463.50
# Min Obs:                       438.00
# Max Obs:                       485.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0693     0.0188    -3.6799     0.0002     -0.1062     -0.0324
# eps_surprise            5.138e-07  7.775e-07     0.6609     0.5087   -1.01e-06   2.038e-06
# f_size                 -6.561e-05  9.891e-05    -0.6633     0.5071     -0.0003      0.0001
# ==========================================================================================
#
# F-test for Poolability: 16.174
# P-value: 0.0000
# Distribution: F(511,12463)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          two_day_r_vol   R-squared:                        0.0008
# Estimator:                   PanelOLS   R-squared (Between):             -0.0858
# No. Observations:               12969   R-squared (Within):               0.0035
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0677
# Time:                        22:30:31   Log-likelihood                 1.322e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      3.2865
# Entities:                         487   P-value                           0.0198
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             3.2865
#                                         P-value                           0.0198
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.0845     0.0281    -3.0113     0.0026     -0.1395     -0.0295
# eps_surprise          -1.286e-07  6.533e-07    -0.1968     0.8440  -1.409e-06   1.152e-06
# f_size                 6.537e-05  7.562e-05     0.8645     0.3873  -8.285e-05      0.0002
# =========================================================================================
#
# F-test for Poolability: 14.627
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         four_day_r_vol   R-squared:                        0.0017
# Estimator:                   PanelOLS   R-squared (Between):             -0.1026
# No. Observations:               12978   R-squared (Within):               0.0066
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0862
# Time:                        22:30:31   Log-likelihood                 1.689e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      7.2241
# Entities:                         485   P-value                           0.0001
# Avg Obs:                       26.759   Distribution:                 F(3,12463)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             7.2241
#                                         P-value                           0.0001
# Time periods:                      28   Distribution:                 F(3,12463)
# Avg Obs:                       463.50
# Min Obs:                       438.00
# Max Obs:                       485.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0755     0.0167    -4.5156     0.0000     -0.1082     -0.0427
# eps_surprise            6.917e-07    6.9e-07     1.0025     0.3161  -6.608e-07   2.044e-06
# f_size                 -5.129e-05  8.778e-05    -0.5842     0.5591     -0.0002      0.0001
# ==========================================================================================
#
# F-test for Poolability: 17.355
# P-value: 0.0000
# Distribution: F(511,12463)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        three_day_r_vol   R-squared:                        0.0010
# Estimator:                   PanelOLS   R-squared (Between):             -0.1182
# No. Observations:               12969   R-squared (Within):               0.0040
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0882
# Time:                        22:30:31   Log-likelihood                 1.274e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.0622
# Entities:                         487   P-value                           0.0068
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             4.0622
#                                         P-value                           0.0068
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1012     0.0291    -3.4766     0.0005     -0.1582     -0.0441
# eps_surprise          -2.386e-07  6.775e-07    -0.3522     0.7247  -1.567e-06   1.089e-06
# f_size                 9.126e-06  7.842e-05     0.1164     0.9074     -0.0001      0.0002
# =========================================================================================
#
# F-test for Poolability: 10.201
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         five_day_r_vol   R-squared:                        0.0017
# Estimator:                   PanelOLS   R-squared (Between):             -0.1004
# No. Observations:               12978   R-squared (Within):               0.0056
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0771
# Time:                        22:30:31   Log-likelihood                 1.421e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.9972
# Entities:                         485   P-value                           0.0001
# Avg Obs:                       26.759   Distribution:                 F(3,12463)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             6.9972
#                                         P-value                           0.0001
# Time periods:                      28   Distribution:                 F(3,12463)
# Avg Obs:                       463.50
# Min Obs:                       438.00
# Max Obs:                       485.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0836     0.0205    -4.0712     0.0000     -0.1239     -0.0434
# eps_surprise            1.007e-07  8.481e-07     0.1187     0.9055  -1.562e-06   1.763e-06
# f_size                     0.0002     0.0001     2.0607     0.0393   1.085e-05      0.0004
# ==========================================================================================
#
# F-test for Poolability: 11.037
# P-value: 0.0000
# Distribution: F(511,12463)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         four_day_r_vol   R-squared:                        0.0011
# Estimator:                   PanelOLS   R-squared (Between):             -0.1310
# No. Observations:               12969   R-squared (Within):               0.0043
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0972
# Time:                        22:30:31   Log-likelihood                 1.307e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.6548
# Entities:                         487   P-value                           0.0030
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             4.6548
#                                         P-value                           0.0030
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1045     0.0284    -3.6827     0.0002     -0.1602     -0.0489
# eps_surprise          -3.255e-07  6.608e-07    -0.4925     0.6224  -1.621e-06   9.698e-07
# f_size                -3.769e-05  7.649e-05    -0.4928     0.6222     -0.0002      0.0001
# =========================================================================================
#
# F-test for Poolability: 9.3163
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          six_day_r_vol   R-squared:                        0.0020
# Estimator:                   PanelOLS   R-squared (Between):             -0.1022
# No. Observations:               12978   R-squared (Within):               0.0063
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0794
# Time:                        22:30:32   Log-likelihood                 1.515e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.1984
# Entities:                         485   P-value                           0.0000
# Avg Obs:                       26.759   Distribution:                 F(3,12463)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             8.1984
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12463)
# Avg Obs:                       463.50
# Min Obs:                       438.00
# Max Obs:                       485.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0827     0.0191    -4.3274     0.0000     -0.1201     -0.0452
# eps_surprise           -4.655e-08  7.889e-07    -0.0590     0.9530  -1.593e-06     1.5e-06
# f_size                     0.0002     0.0001     2.3817     0.0172   4.231e-05      0.0004
# ==========================================================================================
#
# F-test for Poolability: 11.739
# P-value: 0.0000
# Distribution: F(511,12463)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         five_day_r_vol   R-squared:                        0.0014
# Estimator:                   PanelOLS   R-squared (Between):             -0.1395
# No. Observations:               12969   R-squared (Within):               0.0039
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0906
# Time:                        22:30:32   Log-likelihood                 1.039e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      5.6996
# Entities:                         487   P-value                           0.0007
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             5.6996
#                                         P-value                           0.0007
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1242     0.0349    -3.5579     0.0004     -0.1926     -0.0558
# eps_surprise          -2.328e-07  8.126e-07    -0.2865     0.7745  -1.826e-06    1.36e-06
# f_size                    0.0002  9.405e-05     2.0781     0.0377   1.109e-05      0.0004
# =========================================================================================
#
# F-test for Poolability: 6.1198
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        seven_day_r_vol   R-squared:                        0.0016
# Estimator:                   PanelOLS   R-squared (Between):             -0.1001
# No. Observations:               12978   R-squared (Within):               0.0056
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0760
# Time:                        22:30:32   Log-likelihood                  1.49e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.4833
# Entities:                         485   P-value                           0.0002
# Avg Obs:                       26.759   Distribution:                 F(3,12463)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             6.4833
#                                         P-value                           0.0002
# Time periods:                      28   Distribution:                 F(3,12463)
# Avg Obs:                       463.50
# Min Obs:                       438.00
# Max Obs:                       485.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.0777     0.0195    -3.9908     0.0001     -0.1159     -0.0396
# eps_surprise           -1.351e-07  8.043e-07    -0.1680     0.8666  -1.712e-06   1.441e-06
# f_size                     0.0002     0.0001     1.8322     0.0669  -1.309e-05      0.0004
# ==========================================================================================
#
# F-test for Poolability: 11.251
# P-value: 0.0000
# Distribution: F(511,12463)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          six_day_r_vol   R-squared:                        0.0019
# Estimator:                   PanelOLS   R-squared (Between):             -0.1734
# No. Observations:               12969   R-squared (Within):               0.0053
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1147
# Time:                        22:30:32   Log-likelihood                 1.127e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.0345
# Entities:                         487   P-value                           0.0000
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             8.0345
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1443     0.0326    -4.4262     0.0000     -0.2082     -0.0804
# eps_surprise          -1.239e-07  7.591e-07    -0.1632     0.8703  -1.612e-06   1.364e-06
# f_size                    0.0002  8.786e-05     2.1027     0.0355   1.252e-05      0.0004
# =========================================================================================
#
# F-test for Poolability: 6.3850
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           full_q_r_vol   R-squared:                        0.0042
# Estimator:                   PanelOLS   R-squared (Between):             -0.2128
# No. Observations:               12493   R-squared (Within):               0.0074
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1407
# Time:                        22:30:32   Log-likelihood                 1.294e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      16.667
# Entities:                         485   P-value                           0.0000
# Avg Obs:                       25.759   Distribution:                 F(3,11979)
# Min Obs:                       2.0000
# Max Obs:                       27.000   F-statistic (robust):             16.667
#                                         P-value                           0.0000
# Time periods:                      27   Distribution:                 F(3,11979)
# Avg Obs:                       462.70
# Min Obs:                       438.00
# Max Obs:                       484.00
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# avg_default_verbolizer    -0.1036     0.0222    -4.6605     0.0000     -0.1471     -0.0600
# eps_surprise            1.985e-08  9.009e-07     0.0220     0.9824  -1.746e-06   1.786e-06
# f_size                    -0.0007     0.0001    -5.3265     0.0000     -0.0009     -0.0004
# ==========================================================================================
#
# F-test for Poolability: 10.431
# P-value: 0.0000
# Distribution: F(510,11979)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        seven_day_r_vol   R-squared:                        0.0023
# Estimator:                   PanelOLS   R-squared (Between):             -0.1864
# No. Observations:               12969   R-squared (Within):               0.0063
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1255
# Time:                        22:30:32   Log-likelihood                 1.204e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9.7039
# Entities:                         487   P-value                           0.0000
# Avg Obs:                       26.630   Distribution:                 F(3,12452)
# Min Obs:                       1.0000
# Max Obs:                       56.000   F-statistic (robust):             9.7039
#                                         P-value                           0.0000
# Time periods:                      28   Distribution:                 F(3,12452)
# Avg Obs:                       463.18
# Min Obs:                       435.00
# Max Obs:                       488.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# avg_shrink_verbolizer    -0.1503     0.0307    -4.8925     0.0000     -0.2105     -0.0901
# eps_surprise          -1.024e-07  7.152e-07    -0.1432     0.8861  -1.504e-06   1.299e-06
# f_size                    0.0002  8.278e-05     2.2525     0.0243    2.42e-05      0.0003
# =========================================================================================
#
# F-test for Poolability: 6.8673
# P-value: 0.0000
# Distribution: F(513,12452)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           full_q_r_vol   R-squared:                        0.0042
# Estimator:                   PanelOLS   R-squared (Between):             -0.3037
# No. Observations:               12481   R-squared (Within):               0.0098
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.1994
# ...
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# min_shrink_verbolizer    -0.0767     0.0273    -2.8104     0.0050     -0.1302     -0.0232
# eps_surprise          -9.785e-07  1.391e-06    -0.7037     0.4816  -3.704e-06   1.747e-06
# f_size                   -0.0007     0.0002    -3.5862     0.0003     -0.0011     -0.0003
# =========================================================================================
#
# F-test for Poolability: 0.6087
# P-value: 1.0000
# Distribution: F(519,12208)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        three_day_abn_r   R-squared:                        0.0006
# Estimator:                   PanelOLS   R-squared (Between):             -0.0308
# No. Observations:               13297   R-squared (Within):               0.0003
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0010
# Time:                        22:30:36   Log-likelihood                 -2.23e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.4913
# Entities:                         496   P-value                           0.0583
# Avg Obs:                       26.808   Distribution:                 F(3,12771)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             2.4913
#                                         P-value                           0.0583
# Time periods:                      28   Distribution:                 F(3,12771)
# Avg Obs:                       474.89
# Min Obs:                       449.00
# Max Obs:                       496.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# min_shrink_verbolizer     0.3209     0.1843     1.7413     0.0817     -0.0403      0.6820
# eps_surprise          -2.152e-06  1.356e-05    -0.1587     0.8739  -2.873e-05   2.442e-05
# f_size                    0.0036     0.0017     2.1178     0.0342      0.0003      0.0070
# =========================================================================================
#
# F-test for Poolability: 1.0580
# P-value: 0.1787
# Distribution: F(522,12771)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         four_day_abn_r   R-squared:                        0.0006
# Estimator:                   PanelOLS   R-squared (Between):             -0.0336
# No. Observations:               13297   R-squared (Within):               0.0003
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0010
# Time:                        22:30:36   Log-likelihood                -1.994e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.6013
# Entities:                         496   P-value                           0.0503
# Avg Obs:                       26.808   Distribution:                 F(3,12771)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             2.6013
#                                         P-value                           0.0503
# Time periods:                      28   Distribution:                 F(3,12771)
# Avg Obs:                       474.89
# Min Obs:                       449.00
# Max Obs:                       496.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# min_shrink_verbolizer     0.3191     0.1543     2.0677     0.0387      0.0166      0.6217
# eps_surprise           1.668e-06  1.136e-05     0.1469     0.8832  -2.059e-05   2.393e-05
# f_size                    0.0027     0.0014     1.8960     0.0580  -9.256e-05      0.0056
# =========================================================================================
#
# F-test for Poolability: 1.0198
# P-value: 0.3704
# Distribution: F(522,12771)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:         five_day_abn_r   R-squared:                        0.0006
# Estimator:                   PanelOLS   R-squared (Between):             -0.0326
# No. Observations:               13297   R-squared (Within):               0.0003
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0009
# Time:                        22:30:36   Log-likelihood                  -1.8e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.6983
# Entities:                         496   P-value                           0.0441
# Avg Obs:                       26.808   Distribution:                 F(3,12771)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             2.6983
#                                         P-value                           0.0441
# Time periods:                      28   Distribution:                 F(3,12771)
# Avg Obs:                       474.89
# Min Obs:                       449.00
# Max Obs:                       496.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# min_shrink_verbolizer     0.3101     0.1334     2.3248     0.0201      0.0486      0.5716
# eps_surprise           1.774e-06  9.815e-06     0.1807     0.8566  -1.746e-05   2.101e-05
# f_size                    0.0021     0.0012     1.6574     0.0975     -0.0004      0.0045
# =========================================================================================
#
# F-test for Poolability: 1.0087
# P-value: 0.4378
# Distribution: F(522,12771)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:          six_day_abn_r   R-squared:                        0.0004
# Estimator:                   PanelOLS   R-squared (Between):             -0.0294
# No. Observations:               13297   R-squared (Within):               0.0002
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0008
# Time:                        22:30:36   Log-likelihood                -1.644e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.8257
# Entities:                         496   P-value                           0.1401
# Avg Obs:                       26.808   Distribution:                 F(3,12771)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             1.8257
#                                         P-value                           0.1401
# Time periods:                      28   Distribution:                 F(3,12771)
# Avg Obs:                       474.89
# Min Obs:                       449.00
# Max Obs:                       496.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# min_shrink_verbolizer     0.2510     0.1186     2.1160     0.0344      0.0185      0.4835
# eps_surprise           2.459e-06  8.728e-06     0.2817     0.7782  -1.465e-05   1.957e-05
# f_size                    0.0011     0.0011     0.9891     0.3226     -0.0011      0.0033
# =========================================================================================
#
# F-test for Poolability: 1.0160
# P-value: 0.3930
# Distribution: F(522,12771)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        seven_day_abn_r   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):             -0.0254
# No. Observations:               13297   R-squared (Within):            4.893e-05
# Date:                Fri, May 16 2025   R-squared (Overall):             -0.0008
# Time:                        22:30:36   Log-likelihood                -1.528e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.4701
# Entities:                         496   P-value                           0.2205
# Avg Obs:                       26.808   Distribution:                 F(3,12771)
# Min Obs:                       3.0000
# Max Obs:                       28.000   F-statistic (robust):             1.4701
#                                         P-value                           0.2205
# Time periods:                      28   Distribution:                 F(3,12771)
# Avg Obs:                       474.89
# Min Obs:                       449.00
# Max Obs:                       496.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# min_shrink_verbolizer     0.2103     0.1087     1.9349     0.0530     -0.0027      0.4234
# eps_surprise          -1.629e-06  7.998e-06    -0.2037     0.8386  -1.731e-05   1.405e-05
# f_size                    0.0008     0.0010     0.8032     0.4218     -0.0012      0.0028
# =========================================================================================
#
# F-test for Poolability: 0.9929
# P-value: 0.5372
# Distribution: F(522,12771)
#
# Included effects: Entity, Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:           full_q_abn_r   R-squared:                        0.0009
# Estimator:                   PanelOLS   R-squared (Between):             -0.1186
# No. Observations:               12801   R-squared (Within):               0.0016
# Date:                Fri, May 16 2025   R-squared (Overall):          -5.395e-05
# Time:                        22:30:36   Log-likelihood                    2969.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      3.6071
# Entities:                         496   P-value                           0.0128
# Avg Obs:                       25.808   Distribution:                 F(3,12276)
# Min Obs:                       2.0000
# Max Obs:                       27.000   F-statistic (robust):             3.6071
#                                         P-value                           0.0128
# Time periods:                      27   Distribution:                 F(3,12276)
# Avg Obs:                       474.11
# Min Obs:                       449.00
# Max Obs:                       495.00
#
#                                    Parameter Estimates
# =========================================================================================
#                        Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------
# min_shrink_verbolizer    -0.0527     0.0278    -1.8967     0.0579     -0.1072      0.0018
# eps_surprise          -8.339e-07  2.013e-06    -0.4143     0.6787   -4.78e-06   3.112e-06
# f_size                   -0.0008     0.0003    -2.6713     0.0076     -0.0013     -0.0002
# =========================================================================================
#
# F-test for Poolability: 0.6051
# P-value: 1.0000
# Distribution: F(521,12276)
#
# Included effects: Entity, Time
# avg_default_verbolizer ['returns', 'e_returns', 'abn_returns']
# avg_default_verbolizer ['returns', 'e_returns', 'abn_returns']
# avg_default_verbolizer ['returns', 'e_returns', 'abn_returns']
# avg_shrink_verbolizer ['returns', 'e_returns', 'abn_returns']
# avg_shrink_verbolizer ['returns', 'e_returns', 'abn_returns']
# avg_shrink_verbolizer ['returns', 'e_returns', 'abn_returns']
# max_abs_default ['e_returns', 'abn_returns']
# max_abs_default ['e_returns', 'abn_returns']
# max_abs_shrink ['r_vol']
# max_default_verbolizer ['returns', 'e_returns']
# max_default_verbolizer ['returns', 'e_returns']
# max_shrink_verbolizer ['returns', 'e_returns']
# max_shrink_verbolizer ['returns', 'e_returns']
# min_default_verbolizer ['e_returns', 'r_vol']
# min_default_verbolizer ['e_returns', 'r_vol']
# min_shrink_verbolizer ['e_returns', 'r_vol']
# min_shrink_verbolizer ['e_returns', 'r_vol']

# %%
d
# Out:
# {'avg_default_verbolizer': {'r_vol': {'two_day_r_vol': {'beta': [-0.0889,
#      -0.053],
#     'r2': [0.0013, 0.0006],
#     'r2_between': [-0.1021, -0.0652],
#     'r2_within': [0.0052, 0.0024],
#     'r2_overall': [-0.0805, -0.0513]},
#    'three_day_r_vol': {'beta': [-0.0978, -0.0693],
#     'r2': [0.0014, 0.0012],
#     'r2_between': [-0.1283, -0.0907],
#     'r2_within': [0.0053, 0.0049],
#     'r2_overall': [-0.0957, -0.0745]},
#    'four_day_r_vol': {'beta': [-0.0975, -0.0755],
#     'r2': [0.0015, 0.0017],
#     'r2_between': [-0.1371, -0.1026],
#     'r2_within': [0.0054, 0.0066],
#     'r2_overall': [-0.1017, -0.0862]},
#    'five_day_r_vol': {'beta': [-0.1152, -0.0836],
#     'r2': [0.0017, 0.0017],
#     'r2_between': [-0.1458, -0.1004],
#     'r2_within': [0.0048, 0.0056],
#     'r2_overall': [-0.0946, -0.0771]},
#    'six_day_r_vol': {'beta': [-0.1278, -0.0827],
#     'r2': [0.0022, 0.002],
#     'r2_between': [-0.1719, -0.1022],
#     'r2_within': [0.0061, 0.0063],
#     'r2_overall': [-0.1137, -0.0794]},
#    'seven_day_r_vol': {'beta': [-0.1317, -0.0777],
#     'r2': [0.0027, 0.0016],
#     'r2_between': [-0.1826, -0.1001],
#     'r2_within': [0.0071, 0.0056],
#     'r2_overall': [-0.123, -0.076]},
#    'full_q_r_vol': {'beta': [-0.1603, -0.1036],
#     'r2': [0.0042, 0.0042],
#     'r2_between': [-0.2776, -0.2128],
#     'r2_within': [0.0089, 0.0074],
#     'r2_overall': [-0.1826, -0.1407]}}},
#  'avg_shrink_verbolizer': {'r_vol': {'two_day_r_vol': {'beta': [-0.0845,
#      -0.0372],
#     'r2': [0.0008, 0.0003],
#     'r2_between': [-0.0858, -0.0417],
#     'r2_within': [0.0035, 0.001],
#     'r2_overall': [-0.0677, -0.0329]},
#    'three_day_r_vol': {'beta': [-0.1012, -0.0622],
#     'r2': [0.001, 0.0006],
#     'r2_between': [-0.1182, -0.0718],
#     'r2_within': [0.004, 0.003],
#     'r2_overall': [-0.0882, -0.0591]},
#    'four_day_r_vol': {'beta': [-0.1045, -0.0771],
#     'r2': [0.0011, 0.0012],
#     'r2_between': [-0.131, -0.092],
#     'r2_within': [0.0043, 0.0047],
#     'r2_overall': [-0.0972, -0.0774]},
#    'five_day_r_vol': {'beta': [-0.1242, -0.0877],
#     'r2': [0.0014, 0.0013],
#     'r2_between': [-0.1395, -0.0913],
#     'r2_within': [0.0039, 0.0043],
#     'r2_overall': [-0.0906, -0.0702]},
#    'six_day_r_vol': {'beta': [-0.1443, -0.0886],
#     'r2': [0.0019, 0.0016],
#     'r2_between': [-0.1734, -0.0952],
#     'r2_within': [0.0053, 0.005],
#     'r2_overall': [-0.1147, -0.0741]},
#    'seven_day_r_vol': {'beta': [-0.1503, -0.0867],
#     'r2': [0.0023, 0.0013],
#     'r2_between': [-0.1864, -0.0977],
#     'r2_within': [0.0063, 0.0047],
#     'r2_overall': [-0.1255, -0.0743]},
#    'full_q_r_vol': {'beta': [-0.1962, -0.146],
#     'r2': [0.0042, 0.0047],
#     'r2_between': [-0.3037, -0.2548],
#     'r2_within': [0.0098, 0.0089],
#     'r2_overall': [-0.1994, -0.1684]}}},
#  'max_abs_default': {'returns': {'two_day_r': {'beta': [0.7349, 0.2925],
#     'r2': [0.0014, 0.0012],
#     'r2_between': [-0.0053, 0.0083],
#     'r2_within': [0.0014, 0.001],
#     'r2_overall': [0.0006, 0.0011]},
#    'three_day_r': {'beta': [0.5735, 0.2504],
#     'r2': [0.0016, 0.0012],
#     'r2_between': [-0.0065, 0.0216],
#     'r2_within': [0.0015, 0.001],
#     'r2_overall': [0.0009, 0.0016]},
#    'four_day_r': {'beta': [0.2908, 0.1887],
#     'r2': [0.0019, 0.0008],
#     'r2_between': [-0.0305, 0.0553],
#     'r2_within': [0.0017, 0.0008],
#     'r2_overall': [0.0003, 0.0032]},
#    'five_day_r': {'beta': [0.3601, 0.1831],
#     'r2': [0.0029, 0.0007],
#     'r2_between': [-0.047, 0.0738],
#     'r2_within': [0.0024, 0.0008],
#     'r2_overall': [-0.0001, 0.0041]},
#    'six_day_r': {'beta': [0.1929, 0.1269],
#     'r2': [0.0021, 0.0006],
#     'r2_between': [-0.0378, 0.083],
#     'r2_within': [0.0015, 0.0006],
#     'r2_overall': [-0.0006, 0.0043]},
#    'seven_day_r': {'beta': [0.1985, 0.109],
#     'r2': [0.002, 0.0006],
#     'r2_between': [0.0134, 0.0926],
#     'r2_within': [0.0013, 0.0006],
#     'r2_overall': [0.001, 0.0048]},
#    'full_q_r': {'beta': [-0.0666, -0.0369],
#     'r2': [0.0029, 0.0011],
#     'r2_between': [-0.5087, -0.2657],
#     'r2_within': [0.004, 0.0019],
#     'r2_overall': [-0.0461, -0.0247]}},
#   'r_vol': {'two_day_r_vol': {'beta': [-0.0183, -0.0152],
#     'r2': [0.0005, 0.0004],
#     'r2_between': [-0.0405, -0.0407],
#     'r2_within': [0.0022, 0.0014],
#     'r2_overall': [-0.0316, -0.0319]},
#    'three_day_r_vol': {'beta': [-0.0296, -0.0183],
#     'r2': [0.0011, 0.0007],
#     'r2_between': [-0.0792, -0.0509],
#     'r2_within': [0.0032, 0.0024],
#     'r2_overall': [-0.0587, -0.0417]},
#    'four_day_r_vol': {'beta': [-0.029, -0.0205],
#     'r2': [0.0011, 0.0011],
#     'r2_between': [-0.0842, -0.0588],
#     'r2_within': [0.0031, 0.0034],
#     'r2_overall': [-0.0622, -0.0493]},
#    'five_day_r_vol': {'beta': [-0.0237, -0.0153],
#     'r2': [0.0008, 0.0007],
#     'r2_between': [-0.0524, -0.0303],
#     'r2_within': [0.0021, 0.0021],
#     'r2_overall': [-0.0335, -0.0229]},
#    'six_day_r_vol': {'beta': [-0.0244, -0.0128],
#     'r2': [0.0009, 0.0008],
#     'r2_between': [-0.0573, -0.0234],
#     'r2_within': [0.0023, 0.002],
#     'r2_overall': [-0.0374, -0.0179]},
#    'seven_day_r_vol': {'beta': [-0.0239, -0.0046],
#     'r2': [0.001, 0.0003],
#     'r2_between': [-0.0572, -0.0027],
#     'r2_within': [0.0024, 0.0007],
#     'r2_overall': [-0.038, -0.0017]},
#    'full_q_r_vol': {'beta': [-0.0299, -0.0165],
#     'r2': [0.0013, 0.0027],
#     'r2_between': [-0.1071, -0.0988],
#     'r2_within': [0.0024, 0.0037],
#     'r2_overall': [-0.0704, -0.0654]}}},
#  'max_abs_shrink': {'returns': {'two_day_r': {'beta': [0.6011, 0.6087],
#     'r2': [0.0009, 0.0015],
#     'r2_between': [0.0067, 0.0046],
#     'r2_within': [0.0008, 0.0012],
#     'r2_overall': [0.0007, 0.0012]},
#    'three_day_r': {'beta': [0.6332, 0.6636],
#     'r2': [0.0013, 0.0019],
#     'r2_between': [-0.0035, -0.0068],
#     'r2_within': [0.0012, 0.0017],
#     'r2_overall': [0.0008, 0.0009]},
#    'four_day_r': {'beta': [0.3684, 0.4634],
#     'r2': [0.0019, 0.0014],
#     'r2_between': [-0.0328, 0.0571],
#     'r2_within': [0.0018, 0.0014],
#     'r2_overall': [0.0003, 0.0039]},
#    'five_day_r': {'beta': [0.4223, 0.3643],
#     'r2': [0.0027, 0.0011],
#     'r2_between': [-0.0482, 0.0835],
#     'r2_within': [0.0024, 0.0013],
#     'r2_overall': [-0.0002, 0.005]},
#    'six_day_r': {'beta': [0.2251, 0.196],
#     'r2': [0.0021, 0.0007],
#     'r2_between': [-0.0421, 0.0945],
#     'r2_within': [0.0016, 0.0008],
#     'r2_overall': [-0.0007, 0.005]},
#    'seven_day_r': {'beta': [0.2747, 0.1767],
#     'r2': [0.002, 0.0007],
#     'r2_between': [0.0308, 0.1075],
#     'r2_within': [0.0015, 0.0008],
#     'r2_overall': [0.0019, 0.0056]},
#    'full_q_r': {'beta': [-0.0572, -0.0278],
#     'r2': [0.0024, 0.001],
#     'r2_between': [-0.4102, -0.2022],
#     'r2_within': [0.0031, 0.0015],
#     'r2_overall': [-0.0375, -0.0187]}},
#   'e_returns': {'two_day_e_r': {'beta': [0.4353, 0.5076],
#     'r2': [0.0006, 0.0016],
#     'r2_between': [-0.0229, -0.053],
#     'r2_within': [0.0007, 0.0013],
#     'r2_overall': [-0.0007, -0.0013]},
#    'three_day_e_r': {'beta': [0.4196, 0.5282],
#     'r2': [0.0011, 0.0016],
#     'r2_between': [-0.0502, -0.0762],
#     'r2_within': [0.0013, 0.0014],
#     'r2_overall': [-0.0009, -0.002]},
#    'four_day_e_r': {'beta': [0.2852, 0.3733],
#     'r2': [0.002, 0.0013],
#     'r2_between': [-0.0947, -0.036],
#     'r2_within': [0.0023, 0.0012],
#     'r2_overall': [-0.0017, -0.0002]},
#    'five_day_e_r': {'beta': [0.2993, 0.3124],
#     'r2': [0.0024, 0.0011],
#     'r2_between': [-0.1088, -0.0257],
#     'r2_within': [0.0028, 0.0011],
#     'r2_overall': [-0.0022, 0.0002]},
#    'six_day_e_r': {'beta': [0.1561, 0.143],
#     'r2': [0.002, 0.0006],
#     'r2_between': [-0.0989, 0.0029],
#     'r2_within': [0.0023, 0.0005],
#     'r2_overall': [-0.0023, 0.0007]},
#    'seven_day_e_r': {'beta': [0.2254, 0.1358],
#     'r2': [0.002, 0.0006],
#     'r2_between': [-0.0696, 0.0021],
#     'r2_within': [0.0023, 0.0005],
#     'r2_overall': [-0.0012, 0.0007]},
#    'full_q_e_r': {'beta': [-0.047, -0.0175],
#     'r2': [0.0023, 0.0008],
#     'r2_between': [-0.3294, -0.1151],
#     'r2_within': [0.0026, 0.0012],
#     'r2_overall': [-0.017, -0.0059]}},
#   'abn_returns': {'two_day_abn_r': {'beta': [0.4103, 0.5612],
#     'r2': [0.0006, 0.0014],
#     'r2_between': [-0.0166, -0.029],
#     'r2_within': [0.0005, 0.001],
#     'r2_overall': [-0.0006, -0.0011]},
#    'three_day_abn_r': {'beta': [0.423, 0.5756],
#     'r2': [0.0011, 0.0018],
#     'r2_between': [-0.0651, -0.0924],
#     'r2_within': [0.001, 0.0013],
#     'r2_overall': [-0.0018, -0.0031]},
#    'four_day_abn_r': {'beta': [0.3457, 0.4447],
#     'r2': [0.0021, 0.0015],
#     'r2_between': [-0.0928, -0.0711],
#     'r2_within': [0.0021, 0.0011],
#     'r2_overall': [-0.0018, -0.0019]},
#    'five_day_abn_r': {'beta': [0.3561, 0.3815],
#     'r2': [0.0026, 0.0014],
#     'r2_between': [-0.1247, -0.0834],
#     'r2_within': [0.0026, 0.0011],
#     'r2_overall': [-0.0026, -0.0021]},
#    'six_day_abn_r': {'beta': [0.2512, 0.2608],
#     'r2': [0.002, 0.0008],
#     'r2_between': [-0.0849, -0.0349],
#     'r2_within': [0.002, 0.0006],
#     'r2_overall': [-0.0015, -0.0006]},
#    'seven_day_abn_r': {'beta': [0.2973, 0.2403],
#     'r2': [0.0021, 0.0008],
#     'r2_between': [-0.1037, -0.0488],
#     'r2_within': [0.0021, 0.0005],
#     'r2_overall': [-0.0022, -0.0009]},
#    'full_q_abn_r': {'beta': [-0.0029, 0.025],
#     'r2': [0.0011, 0.0007],
#     'r2_between': [-0.2647, -0.0197],
#     'r2_within': [0.0017, 0.0014],
#     'r2_overall': [-0.003, 0.0012]}}},
#  'max_default_verbolizer': {'abn_returns': {'two_day_abn_r': {'beta': [0.9695,
#      0.7425],
#     'r2': [0.0012, 0.0011],
#     'r2_between': [-0.36, -0.1525],
#     'r2_within': [0.0012, 0.0009],
#     'r2_overall': [-0.0161, -0.007]},
#    'three_day_abn_r': {'beta': [0.7063, 0.6641],
#     'r2': [0.0013, 0.001],
#     'r2_between': [-0.335, -0.2325],
#     'r2_within': [0.0014, 0.0009],
#     'r2_overall': [-0.013, -0.0097]},
#    'four_day_abn_r': {'beta': [0.5166, 0.4665],
#     'r2': [0.002, 0.0008],
#     'r2_between': [-0.2567, -0.1477],
#     'r2_within': [0.0023, 0.0006],
#     'r2_overall': [-0.0085, -0.0056]},
#    'five_day_abn_r': {'beta': [0.5655, 0.384],
#     'r2': [0.0027, 0.0007],
#     'r2_between': [-0.4632, -0.1553],
#     'r2_within': [0.0029, 0.0006],
#     'r2_overall': [-0.016, -0.0055]},
#    'six_day_abn_r': {'beta': [0.4748, 0.3166],
#     'r2': [0.0023, 0.0005],
#     'r2_between': [-0.4059, -0.1254],
#     'r2_within': [0.0025, 0.0004],
#     'r2_overall': [-0.0141, -0.0043]},
#    'seven_day_abn_r': {'beta': [0.4737, 0.3161],
#     'r2': [0.0022, 0.0005],
#     'r2_between': [-0.478, -0.1887],
#     'r2_within': [0.0025, 0.0005],
#     'r2_overall': [-0.0166, -0.0058]},
#    'full_q_abn_r': {'beta': [0.0134, 0.0416],
#     'r2': [0.0011, 0.0007],
#     'r2_between': [-0.1661, 0.0386],
#     'r2_within': [0.0019, 0.0017],
#     'r2_overall': [-0.0012, 0.0024]}},
#   'r_vol': {'two_day_r_vol': {'beta': [-0.071, -0.0621],
#     'r2': [0.0018, 0.0014],
#     'r2_between': [-0.1946, -0.1733],
#     'r2_within': [0.0062, 0.0049],
#     'r2_overall': [-0.1529, -0.1356]},
#    'three_day_r_vol': {'beta': [-0.0879, -0.0672],
#     'r2': [0.0025, 0.0022],
#     'r2_between': [-0.2726, -0.2046],
#     'r2_within': [0.0064, 0.0067],
#     'r2_overall': [-0.2029, -0.1678]},
#    'four_day_r_vol': {'beta': [-0.0836, -0.0611],
#     'r2': [0.0024, 0.0024],
#     'r2_between': [-0.2729, -0.1929],
#     'r2_within': [0.0056, 0.0068],
#     'r2_overall': [-0.2021, -0.1622]},
#    'five_day_r_vol': {'beta': [-0.0815, -0.0574],
#     'r2': [0.0018, 0.0017],
#     'r2_between': [-0.2491, -0.1681],
#     'r2_within': [0.0041, 0.0047],
#     'r2_overall': [-0.1619, -0.1296]},
#    'six_day_r_vol': {'beta': [-0.0804, -0.052],
#     'r2': [0.002, 0.0017],
#     'r2_between': [-0.2565, -0.1556],
#     'r2_within': [0.0042, 0.0044],
#     'r2_overall': [-0.1699, -0.1215]},
#    'seven_day_r_vol': {'beta': [-0.0763, -0.0418],
#     'r2': [0.0021, 0.0011],
#     'r2_between': [-0.2485, -0.127],
#     'r2_within': [0.0041, 0.0029],
#     'r2_overall': [-0.1676, -0.0968]},
#    'full_q_r_vol': {'beta': [-0.052, -0.0171],
#     'r2': [0.0011, 0.0025],
#     'r2_between': [-0.2009, -0.106],
#     'r2_within': [0.0002, 0.0025],
#     'r2_overall': [-0.1331, -0.0704]}}},
#  'max_shrink_verbolizer': {'abn_returns': {'two_day_abn_r': {'beta': [0.7831,
#      0.9297],
#     'r2': [0.0006, 0.0011],
#     'r2_between': [-0.1243, -0.1537],
#     'r2_within': [0.0006, 0.0008],
#     'r2_overall': [-0.0058, -0.0071]},
#    'three_day_abn_r': {'beta': [0.701, 0.9382],
#     'r2': [0.001, 0.0013],
#     'r2_between': [-0.2052, -0.3249],
#     'r2_within': [0.001, 0.0009],
#     'r2_overall': [-0.0079, -0.0137]},
#    'four_day_abn_r': {'beta': [0.5135, 0.6607],
#     'r2': [0.0018, 0.0009],
#     'r2_between': [-0.1679, -0.2157],
#     'r2_within': [0.0019, 0.0006],
#     'r2_overall': [-0.0051, -0.0083]},
#    'five_day_abn_r': {'beta': [0.5658, 0.532],
#     'r2': [0.0023, 0.0008],
#     'r2_between': [-0.3016, -0.2117],
#     'r2_within': [0.0025, 0.0006],
#     'r2_overall': [-0.01, -0.0075]},
#    'six_day_abn_r': {'beta': [0.5113, 0.4521],
#     'r2': [0.0021, 0.0006],
#     'r2_between': [-0.3084, -0.1901],
#     'r2_within': [0.0022, 0.0004],
#     'r2_overall': [-0.0105, -0.0065]},
#    'seven_day_abn_r': {'beta': [0.5528, 0.4588],
#     'r2': [0.0021, 0.0007],
#     'r2_between': [-0.4308, -0.2897],
#     'r2_within': [0.0023, 0.0005],
#     'r2_overall': [-0.015, -0.0091]},
#    'full_q_abn_r': {'beta': [0.012, 0.1029],
#     'r2': [0.0011, 0.0011],
#     'r2_between': [-0.1832, -0.1558],
#     'r2_within': [0.0018, 0.0022],
#     'r2_overall': [-0.0016, 0.0002]}},
#   'r_vol': {'two_day_r_vol': {'beta': [-0.0738, -0.076],
#     'r2': [0.0013, 0.0014],
#     'r2_between': [-0.1646, -0.1736],
#     'r2_within': [0.0047, 0.0044],
#     'r2_overall': [-0.1294, -0.1359]},
#    'three_day_r_vol': {'beta': [-0.0907, -0.0817],
#     'r2': [0.0018, 0.0022],
#     'r2_between': [-0.2292, -0.2031],
#     'r2_within': [0.0047, 0.006],
#     'r2_overall': [-0.1707, -0.1666]},
#    'four_day_r_vol': {'beta': [-0.0918, -0.0769],
#     'r2': [0.0019, 0.0025],
#     'r2_between': [-0.2453, -0.1984],
#     'r2_within': [0.0045, 0.0065],
#     'r2_overall': [-0.1819, -0.1668]},
#    'five_day_r_vol': {'beta': [-0.0837, -0.0619],
#     'r2': [0.0014, 0.0014],
#     'r2_between': [-0.2064, -0.1459],
#     'r2_within': [0.003, 0.0037],
#     'r2_overall': [-0.1341, -0.1124]},
#    'six_day_r_vol': {'beta': [-0.0807, -0.0533],
#     'r2': [0.0015, 0.0014],
#     'r2_between': [-0.2069, -0.127],
#     'r2_within': [0.0031, 0.0034],
#     'r2_overall': [-0.1371, -0.099]},
#    'seven_day_r_vol': {'beta': [-0.0799, -0.0465],
#     'r2': [0.0016, 0.0009],
#     'r2_between': [-0.2101, -0.114],
#     'r2_within': [0.0032, 0.0024],
#     'r2_overall': [-0.1417, -0.0869]},
#    'full_q_r_vol': {'beta': [-0.0751, -0.0264],
#     'r2': [0.0015, 0.0025],
#     'r2_between': [-0.2395, -0.1226],
#     'r2_within': [0.0008, 0.0026],
#     'r2_overall': [-0.1587, -0.0815]}}},
#  'min_default_verbolizer': {'returns': {'two_day_r': {'beta': [0.2718, 0.2449],
#     'r2': [0.0006, 0.0011],
#     'r2_between': [-0.0578, -0.025],
#     'r2_within': [0.0006, 0.001],
#     'r2_overall': [-0.0021, -0.0003]},
#    'three_day_r': {'beta': [0.4235, 0.3204],
#     'r2': [0.0008, 0.0011],
#     'r2_between': [-0.0907, -0.033],
#     'r2_within': [0.0008, 0.0011],
#     'r2_overall': [-0.0024, -0.0004]},
#    'four_day_r': {'beta': [0.2847, 0.2851],
#     'r2': [0.0017, 0.0008],
#     'r2_between': [-0.1761, -0.0144],
#     'r2_within': [0.0016, 0.001],
#     'r2_overall': [-0.0051, 0.0004]},
#    'five_day_r': {'beta': [0.3508, 0.3242],
#     'r2': [0.0024, 0.0009],
#     'r2_between': [-0.2325, -0.0202],
#     'r2_within': [0.0022, 0.0013],
#     'r2_overall': [-0.0072, 0.0005]},
#    'six_day_r': {'beta': [0.3121, 0.3116],
#     'r2': [0.0023, 0.0009],
#     'r2_between': [-0.2445, -0.0284],
#     'r2_within': [0.0023, 0.0015],
#     'r2_overall': [-0.0077, 0.0004]},
#    'seven_day_r': {'beta': [0.2944, 0.2816],
#     'r2': [0.0021, 0.001],
#     'r2_between': [-0.2292, -0.0316],
#     'r2_within': [0.0021, 0.0016],
#     'r2_overall': [-0.0085, 0.0002]},
#    'full_q_r': {'beta': [-0.0815, -0.1],
#     'r2': [0.0027, 0.0018],
#     'r2_between': [-0.1197, -0.021],
#     'r2_within': [0.0014, 0.0012],
#     'r2_overall': [-0.0112, -0.0016]}},
#   'abn_returns': {'two_day_abn_r': {'beta': [0.2077, 0.3619],
#     'r2': [0.0002, 0.0008],
#     'r2_between': [-0.0265, -0.0395],
#     'r2_within': [0.0002, 0.0005],
#     'r2_overall': [-0.0009, -0.0012]},
#    'three_day_abn_r': {'beta': [0.1358, 0.227],
#     'r2': [0.0005, 0.0005],
#     'r2_between': [-0.042, -0.0302],
#     'r2_within': [0.0005, 0.0003],
#     'r2_overall': [-0.0012, -0.001]},
#    'four_day_abn_r': {'beta': [0.1309, 0.2088],
#     'r2': [0.0015, 0.0005],
#     'r2_between': [-0.1129, -0.0307],
#     'r2_within': [0.0015, 0.0003],
#     'r2_overall': [-0.003, -0.0009]},
#    'five_day_abn_r': {'beta': [0.2003, 0.2262],
#     'r2': [0.0019, 0.0005],
#     'r2_between': [-0.1308, -0.0337],
#     'r2_within': [0.0018, 0.0003],
#     'r2_overall': [-0.0033, -0.001]},
#    'six_day_abn_r': {'beta': [0.184, 0.1903],
#     'r2': [0.0017, 0.0004],
#     'r2_between': [-0.1207, -0.032],
#     'r2_within': [0.0016, 0.0002],
#     'r2_overall': [-0.003, -0.0009]},
#    'seven_day_abn_r': {'beta': [0.1549, 0.152],
#     'r2': [0.0014, 0.0003],
#     'r2_between': [-0.1044, -0.0255],
#     'r2_within': [0.0013, 4.393],
#     'r2_overall': [-0.0026, -0.0008]},
#    'full_q_abn_r': {'beta': [-0.0429, -0.054],
#     'r2': [0.0014, 0.001],
#     'r2_between': [-0.2231, -0.1041],
#     'r2_within': [0.0022, 0.0017],
#     'r2_overall': [-0.0018, 0.0004]}}},
#  'min_shrink_verbolizer': {'returns': {'two_day_r': {'beta': [0.485, 0.6394],
#     'r2': [0.0006, 0.0013],
#     'r2_between': [-0.0573, -0.0388],
#     'r2_within': [0.0007, 0.0011],
#     'r2_overall': [-0.002, -0.0007]},
#    'three_day_r': {'beta': [0.6288, 0.6181],
#     'r2': [0.001, 0.0014],
#     'r2_between': [-0.0858, -0.0468],
#     'r2_within': [0.001, 0.0014],
#     'r2_overall': [-0.0021, -0.0006]},
#    'four_day_r': {'beta': [0.4409, 0.5099],
#     'r2': [0.0018, 0.0011],
#     'r2_between': [-0.1711, -0.0234],
#     'r2_within': [0.0018, 0.0014],
#     'r2_overall': [-0.0047, 0.0004]},
#    'five_day_r': {'beta': [0.4815, 0.4934],
#     'r2': [0.0025, 0.0011],
#     'r2_between': [-0.2192, -0.0226],
#     'r2_within': [0.0025, 0.0017],
#     'r2_overall': [-0.0064, 0.0008]},
#    'six_day_r': {'beta': [0.4227, 0.4591],
#     'r2': [0.0024, 0.0011],
#     'r2_between': [-0.2268, -0.0274],
#     'r2_within': [0.0026, 0.002],
#     'r2_overall': [-0.0067, 0.001]},
#    'seven_day_r': {'beta': [0.3873, 0.4077],
#     'r2': [0.0022, 0.0012],
#     'r2_between': [-0.2093, -0.0293],
#     'r2_within': [0.0024, 0.002],
#     'r2_overall': [-0.0073, 0.0008]},
#    'full_q_r': {'beta': [-0.1027, -0.0943],
#     'r2': [0.0028, 0.0015],
#     'r2_between': [-0.1415, -0.0551],
#     'r2_within': [0.0012, 0.0008],
#     'r2_overall': [-0.0135, -0.0053]}},
#   'abn_returns': {'two_day_abn_r': {'beta': [0.258, 0.5316],
#     'r2': [0.0003, 0.001],
#     'r2_between': [-0.0225, -0.0401],
#     'r2_within': [0.0002, 0.0005],
#     'r2_overall': [-0.0008, -0.0012]},
#    'three_day_abn_r': {'beta': [0.174, 0.3209],
#     'r2': [0.0005, 0.0006],
#     'r2_between': [-0.0387, -0.0308],
#     'r2_within': [0.0005, 0.0003],
#     'r2_overall': [-0.0011, -0.001]},
#    'four_day_abn_r': {'beta': [0.1688, 0.3191],
#     'r2': [0.0015, 0.0006],
#     'r2_between': [-0.1078, -0.0336],
#     'r2_within': [0.0015, 0.0003],
#     'r2_overall': [-0.0028, -0.001]},
#    'five_day_abn_r': {'beta': [0.2376, 0.3101],
#     'r2': [0.0019, 0.0006],
#     'r2_between': [-0.1206, -0.0326],
#     'r2_within': [0.0017, 0.0003],
#     'r2_overall': [-0.003, -0.0009]},
#    'six_day_abn_r': {'beta': [0.2062, 0.251],
#     'r2': [0.0017, 0.0004],
#     'r2_between': [-0.1085, -0.0294],
#     'r2_within': [0.0015, 0.0002],
#     'r2_overall': [-0.0026, -0.0008]},
#    'seven_day_abn_r': {'beta': [0.1851, 0.2103],
#     'r2': [0.0014, 0.0003],
#     'r2_between': [-0.0953, -0.0254],
#     'r2_within': [0.0012, 4.893],
#     'r2_overall': [-0.0024, -0.0008]},
#    'full_q_abn_r': {'beta': [-0.0767, -0.0527],
#     'r2': [0.0017, 0.0009],
#     'r2_between': [-0.241, -0.1186],
#     'r2_within': [0.0026, 0.0016],
#     'r2_overall': [-0.0017, -5.395]}}}}

# %%
d['avg_default_verbolizer']['r_vol']['two_day_r_vol']
# Out:
# {'beta': [-0.0889, -0.053],
#  'r2': [0.0013, 0.0006],
#  'r2_between': [-0.1021, -0.0652],
#  'r2_within': [0.0052, 0.0024],
#  'r2_overall': [-0.0805, -0.0513]}

# %%
d
# Out:
# {'avg_default_verbolizer': {'r_vol': {'two_day_r_vol': {'beta': [-0.0889,
#      -0.053],
#     'r2': [0.0013, 0.0006],
#     'r2_between': [-0.1021, -0.0652],
#     'r2_within': [0.0052, 0.0024],
#     'r2_overall': [-0.0805, -0.0513]},
#    'three_day_r_vol': {'beta': [-0.0978, -0.0693],
#     'r2': [0.0014, 0.0012],
#     'r2_between': [-0.1283, -0.0907],
#     'r2_within': [0.0053, 0.0049],
#     'r2_overall': [-0.0957, -0.0745]},
#    'four_day_r_vol': {'beta': [-0.0975, -0.0755],
#     'r2': [0.0015, 0.0017],
#     'r2_between': [-0.1371, -0.1026],
#     'r2_within': [0.0054, 0.0066],
#     'r2_overall': [-0.1017, -0.0862]},
#    'five_day_r_vol': {'beta': [-0.1152, -0.0836],
#     'r2': [0.0017, 0.0017],
#     'r2_between': [-0.1458, -0.1004],
#     'r2_within': [0.0048, 0.0056],
#     'r2_overall': [-0.0946, -0.0771]},
#    'six_day_r_vol': {'beta': [-0.1278, -0.0827],
#     'r2': [0.0022, 0.002],
#     'r2_between': [-0.1719, -0.1022],
#     'r2_within': [0.0061, 0.0063],
#     'r2_overall': [-0.1137, -0.0794]},
#    'seven_day_r_vol': {'beta': [-0.1317, -0.0777],
#     'r2': [0.0027, 0.0016],
#     'r2_between': [-0.1826, -0.1001],
#     'r2_within': [0.0071, 0.0056],
#     'r2_overall': [-0.123, -0.076]},
#    'full_q_r_vol': {'beta': [-0.1603, -0.1036],
#     'r2': [0.0042, 0.0042],
#     'r2_between': [-0.2776, -0.2128],
#     'r2_within': [0.0089, 0.0074],
#     'r2_overall': [-0.1826, -0.1407]}}},
#  'avg_shrink_verbolizer': {'r_vol': {'two_day_r_vol': {'beta': [-0.0845,
#      -0.0372],
#     'r2': [0.0008, 0.0003],
#     'r2_between': [-0.0858, -0.0417],
#     'r2_within': [0.0035, 0.001],
#     'r2_overall': [-0.0677, -0.0329]},
#    'three_day_r_vol': {'beta': [-0.1012, -0.0622],
#     'r2': [0.001, 0.0006],
#     'r2_between': [-0.1182, -0.0718],
#     'r2_within': [0.004, 0.003],
#     'r2_overall': [-0.0882, -0.0591]},
#    'four_day_r_vol': {'beta': [-0.1045, -0.0771],
#     'r2': [0.0011, 0.0012],
#     'r2_between': [-0.131, -0.092],
#     'r2_within': [0.0043, 0.0047],
#     'r2_overall': [-0.0972, -0.0774]},
#    'five_day_r_vol': {'beta': [-0.1242, -0.0877],
#     'r2': [0.0014, 0.0013],
#     'r2_between': [-0.1395, -0.0913],
#     'r2_within': [0.0039, 0.0043],
#     'r2_overall': [-0.0906, -0.0702]},
#    'six_day_r_vol': {'beta': [-0.1443, -0.0886],
#     'r2': [0.0019, 0.0016],
#     'r2_between': [-0.1734, -0.0952],
#     'r2_within': [0.0053, 0.005],
#     'r2_overall': [-0.1147, -0.0741]},
#    'seven_day_r_vol': {'beta': [-0.1503, -0.0867],
#     'r2': [0.0023, 0.0013],
#     'r2_between': [-0.1864, -0.0977],
#     'r2_within': [0.0063, 0.0047],
#     'r2_overall': [-0.1255, -0.0743]},
#    'full_q_r_vol': {'beta': [-0.1962, -0.146],
#     'r2': [0.0042, 0.0047],
#     'r2_between': [-0.3037, -0.2548],
#     'r2_within': [0.0098, 0.0089],
#     'r2_overall': [-0.1994, -0.1684]}}},
#  'max_abs_default': {'returns': {'two_day_r': {'beta': [0.7349, 0.2925],
#     'r2': [0.0014, 0.0012],
#     'r2_between': [-0.0053, 0.0083],
#     'r2_within': [0.0014, 0.001],
#     'r2_overall': [0.0006, 0.0011]},
#    'three_day_r': {'beta': [0.5735, 0.2504],
#     'r2': [0.0016, 0.0012],
#     'r2_between': [-0.0065, 0.0216],
#     'r2_within': [0.0015, 0.001],
#     'r2_overall': [0.0009, 0.0016]},
#    'four_day_r': {'beta': [0.2908, 0.1887],
#     'r2': [0.0019, 0.0008],
#     'r2_between': [-0.0305, 0.0553],
#     'r2_within': [0.0017, 0.0008],
#     'r2_overall': [0.0003, 0.0032]},
#    'five_day_r': {'beta': [0.3601, 0.1831],
#     'r2': [0.0029, 0.0007],
#     'r2_between': [-0.047, 0.0738],
#     'r2_within': [0.0024, 0.0008],
#     'r2_overall': [-0.0001, 0.0041]},
#    'six_day_r': {'beta': [0.1929, 0.1269],
#     'r2': [0.0021, 0.0006],
#     'r2_between': [-0.0378, 0.083],
#     'r2_within': [0.0015, 0.0006],
#     'r2_overall': [-0.0006, 0.0043]},
#    'seven_day_r': {'beta': [0.1985, 0.109],
#     'r2': [0.002, 0.0006],
#     'r2_between': [0.0134, 0.0926],
#     'r2_within': [0.0013, 0.0006],
#     'r2_overall': [0.001, 0.0048]},
#    'full_q_r': {'beta': [-0.0666, -0.0369],
#     'r2': [0.0029, 0.0011],
#     'r2_between': [-0.5087, -0.2657],
#     'r2_within': [0.004, 0.0019],
#     'r2_overall': [-0.0461, -0.0247]}},
#   'r_vol': {'two_day_r_vol': {'beta': [-0.0183, -0.0152],
#     'r2': [0.0005, 0.0004],
#     'r2_between': [-0.0405, -0.0407],
#     'r2_within': [0.0022, 0.0014],
#     'r2_overall': [-0.0316, -0.0319]},
#    'three_day_r_vol': {'beta': [-0.0296, -0.0183],
#     'r2': [0.0011, 0.0007],
#     'r2_between': [-0.0792, -0.0509],
#     'r2_within': [0.0032, 0.0024],
#     'r2_overall': [-0.0587, -0.0417]},
#    'four_day_r_vol': {'beta': [-0.029, -0.0205],
#     'r2': [0.0011, 0.0011],
#     'r2_between': [-0.0842, -0.0588],
#     'r2_within': [0.0031, 0.0034],
#     'r2_overall': [-0.0622, -0.0493]},
#    'five_day_r_vol': {'beta': [-0.0237, -0.0153],
#     'r2': [0.0008, 0.0007],
#     'r2_between': [-0.0524, -0.0303],
#     'r2_within': [0.0021, 0.0021],
#     'r2_overall': [-0.0335, -0.0229]},
#    'six_day_r_vol': {'beta': [-0.0244, -0.0128],
#     'r2': [0.0009, 0.0008],
#     'r2_between': [-0.0573, -0.0234],
#     'r2_within': [0.0023, 0.002],
#     'r2_overall': [-0.0374, -0.0179]},
#    'seven_day_r_vol': {'beta': [-0.0239, -0.0046],
#     'r2': [0.001, 0.0003],
#     'r2_between': [-0.0572, -0.0027],
#     'r2_within': [0.0024, 0.0007],
#     'r2_overall': [-0.038, -0.0017]},
#    'full_q_r_vol': {'beta': [-0.0299, -0.0165],
#     'r2': [0.0013, 0.0027],
#     'r2_between': [-0.1071, -0.0988],
#     'r2_within': [0.0024, 0.0037],
#     'r2_overall': [-0.0704, -0.0654]}}},
#  'max_abs_shrink': {'returns': {'two_day_r': {'beta': [0.6011, 0.6087],
#     'r2': [0.0009, 0.0015],
#     'r2_between': [0.0067, 0.0046],
#     'r2_within': [0.0008, 0.0012],
#     'r2_overall': [0.0007, 0.0012]},
#    'three_day_r': {'beta': [0.6332, 0.6636],
#     'r2': [0.0013, 0.0019],
#     'r2_between': [-0.0035, -0.0068],
#     'r2_within': [0.0012, 0.0017],
#     'r2_overall': [0.0008, 0.0009]},
#    'four_day_r': {'beta': [0.3684, 0.4634],
#     'r2': [0.0019, 0.0014],
#     'r2_between': [-0.0328, 0.0571],
#     'r2_within': [0.0018, 0.0014],
#     'r2_overall': [0.0003, 0.0039]},
#    'five_day_r': {'beta': [0.4223, 0.3643],
#     'r2': [0.0027, 0.0011],
#     'r2_between': [-0.0482, 0.0835],
#     'r2_within': [0.0024, 0.0013],
#     'r2_overall': [-0.0002, 0.005]},
#    'six_day_r': {'beta': [0.2251, 0.196],
#     'r2': [0.0021, 0.0007],
#     'r2_between': [-0.0421, 0.0945],
#     'r2_within': [0.0016, 0.0008],
#     'r2_overall': [-0.0007, 0.005]},
#    'seven_day_r': {'beta': [0.2747, 0.1767],
#     'r2': [0.002, 0.0007],
#     'r2_between': [0.0308, 0.1075],
#     'r2_within': [0.0015, 0.0008],
#     'r2_overall': [0.0019, 0.0056]},
#    'full_q_r': {'beta': [-0.0572, -0.0278],
#     'r2': [0.0024, 0.001],
#     'r2_between': [-0.4102, -0.2022],
#     'r2_within': [0.0031, 0.0015],
#     'r2_overall': [-0.0375, -0.0187]}},
#   'e_returns': {'two_day_e_r': {'beta': [0.4353, 0.5076],
#     'r2': [0.0006, 0.0016],
#     'r2_between': [-0.0229, -0.053],
#     'r2_within': [0.0007, 0.0013],
#     'r2_overall': [-0.0007, -0.0013]},
#    'three_day_e_r': {'beta': [0.4196, 0.5282],
#     'r2': [0.0011, 0.0016],
#     'r2_between': [-0.0502, -0.0762],
#     'r2_within': [0.0013, 0.0014],
#     'r2_overall': [-0.0009, -0.002]},
#    'four_day_e_r': {'beta': [0.2852, 0.3733],
#     'r2': [0.002, 0.0013],
#     'r2_between': [-0.0947, -0.036],
#     'r2_within': [0.0023, 0.0012],
#     'r2_overall': [-0.0017, -0.0002]},
#    'five_day_e_r': {'beta': [0.2993, 0.3124],
#     'r2': [0.0024, 0.0011],
#     'r2_between': [-0.1088, -0.0257],
#     'r2_within': [0.0028, 0.0011],
#     'r2_overall': [-0.0022, 0.0002]},
#    'six_day_e_r': {'beta': [0.1561, 0.143],
#     'r2': [0.002, 0.0006],
#     'r2_between': [-0.0989, 0.0029],
#     'r2_within': [0.0023, 0.0005],
#     'r2_overall': [-0.0023, 0.0007]},
#    'seven_day_e_r': {'beta': [0.2254, 0.1358],
#     'r2': [0.002, 0.0006],
#     'r2_between': [-0.0696, 0.0021],
#     'r2_within': [0.0023, 0.0005],
#     'r2_overall': [-0.0012, 0.0007]},
#    'full_q_e_r': {'beta': [-0.047, -0.0175],
#     'r2': [0.0023, 0.0008],
#     'r2_between': [-0.3294, -0.1151],
#     'r2_within': [0.0026, 0.0012],
#     'r2_overall': [-0.017, -0.0059]}},
#   'abn_returns': {'two_day_abn_r': {'beta': [0.4103, 0.5612],
#     'r2': [0.0006, 0.0014],
#     'r2_between': [-0.0166, -0.029],
#     'r2_within': [0.0005, 0.001],
#     'r2_overall': [-0.0006, -0.0011]},
#    'three_day_abn_r': {'beta': [0.423, 0.5756],
#     'r2': [0.0011, 0.0018],
#     'r2_between': [-0.0651, -0.0924],
#     'r2_within': [0.001, 0.0013],
#     'r2_overall': [-0.0018, -0.0031]},
#    'four_day_abn_r': {'beta': [0.3457, 0.4447],
#     'r2': [0.0021, 0.0015],
#     'r2_between': [-0.0928, -0.0711],
#     'r2_within': [0.0021, 0.0011],
#     'r2_overall': [-0.0018, -0.0019]},
#    'five_day_abn_r': {'beta': [0.3561, 0.3815],
#     'r2': [0.0026, 0.0014],
#     'r2_between': [-0.1247, -0.0834],
#     'r2_within': [0.0026, 0.0011],
#     'r2_overall': [-0.0026, -0.0021]},
#    'six_day_abn_r': {'beta': [0.2512, 0.2608],
#     'r2': [0.002, 0.0008],
#     'r2_between': [-0.0849, -0.0349],
#     'r2_within': [0.002, 0.0006],
#     'r2_overall': [-0.0015, -0.0006]},
#    'seven_day_abn_r': {'beta': [0.2973, 0.2403],
#     'r2': [0.0021, 0.0008],
#     'r2_between': [-0.1037, -0.0488],
#     'r2_within': [0.0021, 0.0005],
#     'r2_overall': [-0.0022, -0.0009]},
#    'full_q_abn_r': {'beta': [-0.0029, 0.025],
#     'r2': [0.0011, 0.0007],
#     'r2_between': [-0.2647, -0.0197],
#     'r2_within': [0.0017, 0.0014],
#     'r2_overall': [-0.003, 0.0012]}}},
#  'max_default_verbolizer': {'abn_returns': {'two_day_abn_r': {'beta': [0.9695,
#      0.7425],
#     'r2': [0.0012, 0.0011],
#     'r2_between': [-0.36, -0.1525],
#     'r2_within': [0.0012, 0.0009],
#     'r2_overall': [-0.0161, -0.007]},
#    'three_day_abn_r': {'beta': [0.7063, 0.6641],
#     'r2': [0.0013, 0.001],
#     'r2_between': [-0.335, -0.2325],
#     'r2_within': [0.0014, 0.0009],
#     'r2_overall': [-0.013, -0.0097]},
#    'four_day_abn_r': {'beta': [0.5166, 0.4665],
#     'r2': [0.002, 0.0008],
#     'r2_between': [-0.2567, -0.1477],
#     'r2_within': [0.0023, 0.0006],
#     'r2_overall': [-0.0085, -0.0056]},
#    'five_day_abn_r': {'beta': [0.5655, 0.384],
#     'r2': [0.0027, 0.0007],
#     'r2_between': [-0.4632, -0.1553],
#     'r2_within': [0.0029, 0.0006],
#     'r2_overall': [-0.016, -0.0055]},
#    'six_day_abn_r': {'beta': [0.4748, 0.3166],
#     'r2': [0.0023, 0.0005],
#     'r2_between': [-0.4059, -0.1254],
#     'r2_within': [0.0025, 0.0004],
#     'r2_overall': [-0.0141, -0.0043]},
#    'seven_day_abn_r': {'beta': [0.4737, 0.3161],
#     'r2': [0.0022, 0.0005],
#     'r2_between': [-0.478, -0.1887],
#     'r2_within': [0.0025, 0.0005],
#     'r2_overall': [-0.0166, -0.0058]},
#    'full_q_abn_r': {'beta': [0.0134, 0.0416],
#     'r2': [0.0011, 0.0007],
#     'r2_between': [-0.1661, 0.0386],
#     'r2_within': [0.0019, 0.0017],
#     'r2_overall': [-0.0012, 0.0024]}},
#   'r_vol': {'two_day_r_vol': {'beta': [-0.071, -0.0621],
#     'r2': [0.0018, 0.0014],
#     'r2_between': [-0.1946, -0.1733],
#     'r2_within': [0.0062, 0.0049],
#     'r2_overall': [-0.1529, -0.1356]},
#    'three_day_r_vol': {'beta': [-0.0879, -0.0672],
#     'r2': [0.0025, 0.0022],
#     'r2_between': [-0.2726, -0.2046],
#     'r2_within': [0.0064, 0.0067],
#     'r2_overall': [-0.2029, -0.1678]},
#    'four_day_r_vol': {'beta': [-0.0836, -0.0611],
#     'r2': [0.0024, 0.0024],
#     'r2_between': [-0.2729, -0.1929],
#     'r2_within': [0.0056, 0.0068],
#     'r2_overall': [-0.2021, -0.1622]},
#    'five_day_r_vol': {'beta': [-0.0815, -0.0574],
#     'r2': [0.0018, 0.0017],
#     'r2_between': [-0.2491, -0.1681],
#     'r2_within': [0.0041, 0.0047],
#     'r2_overall': [-0.1619, -0.1296]},
#    'six_day_r_vol': {'beta': [-0.0804, -0.052],
#     'r2': [0.002, 0.0017],
#     'r2_between': [-0.2565, -0.1556],
#     'r2_within': [0.0042, 0.0044],
#     'r2_overall': [-0.1699, -0.1215]},
#    'seven_day_r_vol': {'beta': [-0.0763, -0.0418],
#     'r2': [0.0021, 0.0011],
#     'r2_between': [-0.2485, -0.127],
#     'r2_within': [0.0041, 0.0029],
#     'r2_overall': [-0.1676, -0.0968]},
#    'full_q_r_vol': {'beta': [-0.052, -0.0171],
#     'r2': [0.0011, 0.0025],
#     'r2_between': [-0.2009, -0.106],
#     'r2_within': [0.0002, 0.0025],
#     'r2_overall': [-0.1331, -0.0704]}}},
#  'max_shrink_verbolizer': {'abn_returns': {'two_day_abn_r': {'beta': [0.7831,
#      0.9297],
#     'r2': [0.0006, 0.0011],
#     'r2_between': [-0.1243, -0.1537],
#     'r2_within': [0.0006, 0.0008],
#     'r2_overall': [-0.0058, -0.0071]},
#    'three_day_abn_r': {'beta': [0.701, 0.9382],
#     'r2': [0.001, 0.0013],
#     'r2_between': [-0.2052, -0.3249],
#     'r2_within': [0.001, 0.0009],
#     'r2_overall': [-0.0079, -0.0137]},
#    'four_day_abn_r': {'beta': [0.5135, 0.6607],
#     'r2': [0.0018, 0.0009],
#     'r2_between': [-0.1679, -0.2157],
#     'r2_within': [0.0019, 0.0006],
#     'r2_overall': [-0.0051, -0.0083]},
#    'five_day_abn_r': {'beta': [0.5658, 0.532],
#     'r2': [0.0023, 0.0008],
#     'r2_between': [-0.3016, -0.2117],
#     'r2_within': [0.0025, 0.0006],
#     'r2_overall': [-0.01, -0.0075]},
#    'six_day_abn_r': {'beta': [0.5113, 0.4521],
#     'r2': [0.0021, 0.0006],
#     'r2_between': [-0.3084, -0.1901],
#     'r2_within': [0.0022, 0.0004],
#     'r2_overall': [-0.0105, -0.0065]},
#    'seven_day_abn_r': {'beta': [0.5528, 0.4588],
#     'r2': [0.0021, 0.0007],
#     'r2_between': [-0.4308, -0.2897],
#     'r2_within': [0.0023, 0.0005],
#     'r2_overall': [-0.015, -0.0091]},
#    'full_q_abn_r': {'beta': [0.012, 0.1029],
#     'r2': [0.0011, 0.0011],
#     'r2_between': [-0.1832, -0.1558],
#     'r2_within': [0.0018, 0.0022],
#     'r2_overall': [-0.0016, 0.0002]}},
#   'r_vol': {'two_day_r_vol': {'beta': [-0.0738, -0.076],
#     'r2': [0.0013, 0.0014],
#     'r2_between': [-0.1646, -0.1736],
#     'r2_within': [0.0047, 0.0044],
#     'r2_overall': [-0.1294, -0.1359]},
#    'three_day_r_vol': {'beta': [-0.0907, -0.0817],
#     'r2': [0.0018, 0.0022],
#     'r2_between': [-0.2292, -0.2031],
#     'r2_within': [0.0047, 0.006],
#     'r2_overall': [-0.1707, -0.1666]},
#    'four_day_r_vol': {'beta': [-0.0918, -0.0769],
#     'r2': [0.0019, 0.0025],
#     'r2_between': [-0.2453, -0.1984],
#     'r2_within': [0.0045, 0.0065],
#     'r2_overall': [-0.1819, -0.1668]},
#    'five_day_r_vol': {'beta': [-0.0837, -0.0619],
#     'r2': [0.0014, 0.0014],
#     'r2_between': [-0.2064, -0.1459],
#     'r2_within': [0.003, 0.0037],
#     'r2_overall': [-0.1341, -0.1124]},
#    'six_day_r_vol': {'beta': [-0.0807, -0.0533],
#     'r2': [0.0015, 0.0014],
#     'r2_between': [-0.2069, -0.127],
#     'r2_within': [0.0031, 0.0034],
#     'r2_overall': [-0.1371, -0.099]},
#    'seven_day_r_vol': {'beta': [-0.0799, -0.0465],
#     'r2': [0.0016, 0.0009],
#     'r2_between': [-0.2101, -0.114],
#     'r2_within': [0.0032, 0.0024],
#     'r2_overall': [-0.1417, -0.0869]},
#    'full_q_r_vol': {'beta': [-0.0751, -0.0264],
#     'r2': [0.0015, 0.0025],
#     'r2_between': [-0.2395, -0.1226],
#     'r2_within': [0.0008, 0.0026],
#     'r2_overall': [-0.1587, -0.0815]}}},
#  'min_default_verbolizer': {'returns': {'two_day_r': {'beta': [0.2718, 0.2449],
#     'r2': [0.0006, 0.0011],
#     'r2_between': [-0.0578, -0.025],
#     'r2_within': [0.0006, 0.001],
#     'r2_overall': [-0.0021, -0.0003]},
#    'three_day_r': {'beta': [0.4235, 0.3204],
#     'r2': [0.0008, 0.0011],
#     'r2_between': [-0.0907, -0.033],
#     'r2_within': [0.0008, 0.0011],
#     'r2_overall': [-0.0024, -0.0004]},
#    'four_day_r': {'beta': [0.2847, 0.2851],
#     'r2': [0.0017, 0.0008],
#     'r2_between': [-0.1761, -0.0144],
#     'r2_within': [0.0016, 0.001],
#     'r2_overall': [-0.0051, 0.0004]},
#    'five_day_r': {'beta': [0.3508, 0.3242],
#     'r2': [0.0024, 0.0009],
#     'r2_between': [-0.2325, -0.0202],
#     'r2_within': [0.0022, 0.0013],
#     'r2_overall': [-0.0072, 0.0005]},
#    'six_day_r': {'beta': [0.3121, 0.3116],
#     'r2': [0.0023, 0.0009],
#     'r2_between': [-0.2445, -0.0284],
#     'r2_within': [0.0023, 0.0015],
#     'r2_overall': [-0.0077, 0.0004]},
#    'seven_day_r': {'beta': [0.2944, 0.2816],
#     'r2': [0.0021, 0.001],
#     'r2_between': [-0.2292, -0.0316],
#     'r2_within': [0.0021, 0.0016],
#     'r2_overall': [-0.0085, 0.0002]},
#    'full_q_r': {'beta': [-0.0815, -0.1],
#     'r2': [0.0027, 0.0018],
#     'r2_between': [-0.1197, -0.021],
#     'r2_within': [0.0014, 0.0012],
#     'r2_overall': [-0.0112, -0.0016]}},
#   'abn_returns': {'two_day_abn_r': {'beta': [0.2077, 0.3619],
#     'r2': [0.0002, 0.0008],
#     'r2_between': [-0.0265, -0.0395],
#     'r2_within': [0.0002, 0.0005],
#     'r2_overall': [-0.0009, -0.0012]},
#    'three_day_abn_r': {'beta': [0.1358, 0.227],
#     'r2': [0.0005, 0.0005],
#     'r2_between': [-0.042, -0.0302],
#     'r2_within': [0.0005, 0.0003],
#     'r2_overall': [-0.0012, -0.001]},
#    'four_day_abn_r': {'beta': [0.1309, 0.2088],
#     'r2': [0.0015, 0.0005],
#     'r2_between': [-0.1129, -0.0307],
#     'r2_within': [0.0015, 0.0003],
#     'r2_overall': [-0.003, -0.0009]},
#    'five_day_abn_r': {'beta': [0.2003, 0.2262],
#     'r2': [0.0019, 0.0005],
#     'r2_between': [-0.1308, -0.0337],
#     'r2_within': [0.0018, 0.0003],
#     'r2_overall': [-0.0033, -0.001]},
#    'six_day_abn_r': {'beta': [0.184, 0.1903],
#     'r2': [0.0017, 0.0004],
#     'r2_between': [-0.1207, -0.032],
#     'r2_within': [0.0016, 0.0002],
#     'r2_overall': [-0.003, -0.0009]},
#    'seven_day_abn_r': {'beta': [0.1549, 0.152],
#     'r2': [0.0014, 0.0003],
#     'r2_between': [-0.1044, -0.0255],
#     'r2_within': [0.0013, 4.393],
#     'r2_overall': [-0.0026, -0.0008]},
#    'full_q_abn_r': {'beta': [-0.0429, -0.054],
#     'r2': [0.0014, 0.001],
#     'r2_between': [-0.2231, -0.1041],
#     'r2_within': [0.0022, 0.0017],
#     'r2_overall': [-0.0018, 0.0004]}}},
#  'min_shrink_verbolizer': {'returns': {'two_day_r': {'beta': [0.485, 0.6394],
#     'r2': [0.0006, 0.0013],
#     'r2_between': [-0.0573, -0.0388],
#     'r2_within': [0.0007, 0.0011],
#     'r2_overall': [-0.002, -0.0007]},
#    'three_day_r': {'beta': [0.6288, 0.6181],
#     'r2': [0.001, 0.0014],
#     'r2_between': [-0.0858, -0.0468],
#     'r2_within': [0.001, 0.0014],
#     'r2_overall': [-0.0021, -0.0006]},
#    'four_day_r': {'beta': [0.4409, 0.5099],
#     'r2': [0.0018, 0.0011],
#     'r2_between': [-0.1711, -0.0234],
#     'r2_within': [0.0018, 0.0014],
#     'r2_overall': [-0.0047, 0.0004]},
#    'five_day_r': {'beta': [0.4815, 0.4934],
#     'r2': [0.0025, 0.0011],
#     'r2_between': [-0.2192, -0.0226],
#     'r2_within': [0.0025, 0.0017],
#     'r2_overall': [-0.0064, 0.0008]},
#    'six_day_r': {'beta': [0.4227, 0.4591],
#     'r2': [0.0024, 0.0011],
#     'r2_between': [-0.2268, -0.0274],
#     'r2_within': [0.0026, 0.002],
#     'r2_overall': [-0.0067, 0.001]},
#    'seven_day_r': {'beta': [0.3873, 0.4077],
#     'r2': [0.0022, 0.0012],
#     'r2_between': [-0.2093, -0.0293],
#     'r2_within': [0.0024, 0.002],
#     'r2_overall': [-0.0073, 0.0008]},
#    'full_q_r': {'beta': [-0.1027, -0.0943],
#     'r2': [0.0028, 0.0015],
#     'r2_between': [-0.1415, -0.0551],
#     'r2_within': [0.0012, 0.0008],
#     'r2_overall': [-0.0135, -0.0053]}},
#   'abn_returns': {'two_day_abn_r': {'beta': [0.258, 0.5316],
#     'r2': [0.0003, 0.001],
#     'r2_between': [-0.0225, -0.0401],
#     'r2_within': [0.0002, 0.0005],
#     'r2_overall': [-0.0008, -0.0012]},
#    'three_day_abn_r': {'beta': [0.174, 0.3209],
#     'r2': [0.0005, 0.0006],
#     'r2_between': [-0.0387, -0.0308],
#     'r2_within': [0.0005, 0.0003],
#     'r2_overall': [-0.0011, -0.001]},
#    'four_day_abn_r': {'beta': [0.1688, 0.3191],
#     'r2': [0.0015, 0.0006],
#     'r2_between': [-0.1078, -0.0336],
#     'r2_within': [0.0015, 0.0003],
#     'r2_overall': [-0.0028, -0.001]},
#    'five_day_abn_r': {'beta': [0.2376, 0.3101],
#     'r2': [0.0019, 0.0006],
#     'r2_between': [-0.1206, -0.0326],
#     'r2_within': [0.0017, 0.0003],
#     'r2_overall': [-0.003, -0.0009]},
#    'six_day_abn_r': {'beta': [0.2062, 0.251],
#     'r2': [0.0017, 0.0004],
#     'r2_between': [-0.1085, -0.0294],
#     'r2_within': [0.0015, 0.0002],
#     'r2_overall': [-0.0026, -0.0008]},
#    'seven_day_abn_r': {'beta': [0.1851, 0.2103],
#     'r2': [0.0014, 0.0003],
#     'r2_between': [-0.0953, -0.0254],
#     'r2_within': [0.0012, 4.893],
#     'r2_overall': [-0.0024, -0.0008]},
#    'full_q_abn_r': {'beta': [-0.0767, -0.0527],
#     'r2': [0.0017, 0.0009],
#     'r2_between': [-0.241, -0.1186],
#     'r2_within': [0.0026, 0.0016],
#     'r2_overall': [-0.0017, -5.395]}}}}
