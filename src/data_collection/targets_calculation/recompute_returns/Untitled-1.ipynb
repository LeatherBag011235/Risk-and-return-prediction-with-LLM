# %%
import yfinance as yf
import pandas as pd
import numpy as np
import time
import logging
import statsmodels.api as sm
from datetime import date
from pathlib import Path

# %%
stock = yf.Ticker("WBA")
data = stock.history(start="2018-01-01", end="2019-01-01")
data
# Out:
# $WBA: possibly delisted; no price data found  (1d 2018-01-01 -> 2019-01-01) (Yahoo error = "No data found, symbol may be delisted")
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
data = stock.history(start="2018-01-01", end="2019-01-01")
# Out:
# $BRK_B: possibly delisted; no timezone found
